# %% [markdown]
# # Introduction

# %% [markdown]
# This is a part of milestone project I have done, it was related to healthcare business which included muliple questions were answered.
#
# In this part, I am going to explain step by step with more details how can analyze reqular texts were takeen from a hospital system specifically an emergency data within the first quarter of 2021 by using python with some libraries.

# %% [markdown]
# ## Strategy

# %% [markdown]
# ![Screen%20Shot%201442-11-22%20at%207.38.34%20AM.png](attachment:Screen%20Shot%201442-11-22%20at%207.38.34%20AM.png)

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# There were critical questions I should answers them, these questions were related to patientes who came to an emergency department and received medical consultations. Some of them did not need medical consultations while others had getten it.
#
# These the following questions I had getting from Quality departement in that hospital:
#
# 1. How many patients who did or did not receive medical consulations?
# 2. What were total consultations for each patient? As you know some status recieve more than a one consultation.
# 3. How long consumeed consultation or the duration betweeen the request and reply?
# 4. Did there any consultatios without reply? If yes, how many did have?

# %% [markdown]
# # Explore Data

# %%
# Load data
import numpy as np
import pandas as pd

# plot data
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
plt.style.use('fivethirtyeight')

# datetime library
import datetime

# the figure on cell 
# %matplotlib inline

# %%
# load data
df = pd.read_excel('Al-Noor Laboratory/big project.xlsx')

# %%
# consultations dataframe
consultations = df.loc[:,['CONSULTATIONS']]

# %%
# the first 10 rows of counsultaions
consultations.head(10)
# Out:
#                                        CONSULTATIONS
# 0                                                NaN
# 1    Request:01-01-2021 23:38 Reply:02-01-2021 00:36
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  Request:02-01-2021 00:40 Reply:02-01-2021 01:2...
# 7    Request:02-01-2021 00:49 Reply:02-01-2021 01:39
# 8    Request:02-01-2021 03:24 Reply:02-01-2021 04:06
# 9                                                NaN

# %% [markdown]
# As you saw above, we have null values.

# %%
# shape of consultations (rows, columns)
consultations.shape
# Out:
# (29956, 1)

# %% [markdown]
# **How many patients who did or did not receive medical consulations?**

# %%
print(f'There were {consultations.isna().sum()[0]} patients had not received consultations.')
# Out:
# There were 18448 patients had not received consultations.

# %%
print(f'There were {consultations[~consultations.isna()].shape[0] - consultations.isna().sum()[0]} patient had recieved consultations.')
# Out:
# There were 11508 patient had recieved consultations.

# %% [markdown]
# Let us discover consultation values

# %%
# display the index no six of consultations 
consultations.iloc[6][0]
# Out:
# 'Request:02-01-2021 00:40 Reply:02-01-2021 01:21;Request:02-01-2021 00:49 Reply:02-01-2021 01:30'

# %% [markdown]
# As we saw above, we have two consultations each one has a request and reply date time :
# - Request date: this the date when an emergency physician ordered a consultation
# - Reply date: this the date when a consultation doctor response

# %% [markdown]
# ## Extract Dates Times from Text

# %% [markdown]
# Here, we should think on strategy to extract date time of request and replay, then compute the duration by subtracte reply from request.
#
# As we noted above, each single consultation seperated by semicolon `;` for others, and this will help us and by use `split function` with semicolon `;` we can convert text (string) to list.
#
# so our strategy as following:
# 1. convert text (string) to list by seperating each single consultation by use `split` function with ';'
# 2. determine all indexes of request and reply date time
# 3. compute the duration between request and reply
# 4. re-confirm all dates times correctly extracted
#
# Let us do it.

# %% [markdown]
# ### 1. convert text (string) to list

# %% [markdown]
# we can split each value with two ways:
# 1. by using dictionary comperhension and use `split` function with string
# 2. by using `apply` and `lambda` functions then use `split` function with string

# %%
consultations.apply(lambda x: x.split(';'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-56d8121dbb1f> in <module>
# ----> 1 consultations.apply(lambda x: x.split(';'))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-12-56d8121dbb1f> in <lambda>(x)
# ----> 1 consultations.apply(lambda x: x.split(';'))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %% [markdown]
# Why this error ?
# - Because we have null values "NaN" as float, as we know float has not attribute called "split"
#
# How can we solve this issue?
# - Remving null values by using mask then we can split text (string) to list
#
# Let us do it

# %%
# create mask to determine all null values as True otherwise as False
mask = consultations.isna()
mask
# Out:
#        CONSULTATIONS
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True
# ...              ...
# 29951          False
# 29952          False
# 29953           True
# 29954          False
# 29955          False
#
# [29956 rows x 1 columns]

# %% [markdown]
# then we catch all non null values with a sign not `~` before mask

# %%
consultation_without_null_vals = consultations[~mask]
consultation_without_null_vals
# Out:
#                                            CONSULTATIONS
# 0                                                    NaN
# 1        Request:01-01-2021 23:38 Reply:02-01-2021 00:36
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 29951    Request:31-03-2021 18:58 Reply:01-04-2021 00:37
# 29952  Request:31-03-2021 14:21 Reply:31-03-2021 14:3...
# 29953                                                NaN
# 29954    Request:31-03-2021 15:13 Reply:31-03-2021 16:19
# 29955    Request:31-03-2021 14:37 Reply:31-03-2021 19:13
#
# [29956 rows x 1 columns]

# %% [markdown]
# Why the mask which we applied does not work ? let's think more about this issue.

# %% [markdown]
# let's try to apply the sign `not` with series not dataframe:
# - let's take the consultations as a series without frame
# - then create mask with null values
# - and remove null values by use the sign `not`

# %% [markdown]
# consultations feature (series)

# %%
series_consult = consultations.iloc[:,0]
series_consult
# Out:
# 0                                                      NaN
# 1          Request:01-01-2021 23:38 Reply:02-01-2021 00:36
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 29951      Request:31-03-2021 18:58 Reply:01-04-2021 00:37
# 29952    Request:31-03-2021 14:21 Reply:31-03-2021 14:3...
# 29953                                                  NaN
# 29954      Request:31-03-2021 15:13 Reply:31-03-2021 16:19
# 29955      Request:31-03-2021 14:37 Reply:31-03-2021 19:13
# Name: CONSULTATIONS, Length: 29956, dtype: object

# %% [markdown]
# create mask

# %%
mask = series_consult.isna()
mask
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 29951    False
# 29952    False
# 29953     True
# 29954    False
# 29955    False
# Name: CONSULTATIONS, Length: 29956, dtype: bool

# %% [markdown]
# Remove all null values from consultations

# %%
series_consult_without_null_vals = series_consult[~mask]
series_consult_without_null_vals
# Out:
# 1          Request:01-01-2021 23:38 Reply:02-01-2021 00:36
# 6        Request:02-01-2021 00:40 Reply:02-01-2021 01:2...
# 7          Request:02-01-2021 00:49 Reply:02-01-2021 01:39
# 8          Request:02-01-2021 03:24 Reply:02-01-2021 04:06
# 11         Request:01-01-2021 23:46 Reply:02-01-2021 00:29
#                                ...
# 29950      Request:31-03-2021 18:01 Reply:31-03-2021 18:12
# 29951      Request:31-03-2021 18:58 Reply:01-04-2021 00:37
# 29952    Request:31-03-2021 14:21 Reply:31-03-2021 14:3...
# 29954      Request:31-03-2021 15:13 Reply:31-03-2021 16:19
# 29955      Request:31-03-2021 14:37 Reply:31-03-2021 19:13
# Name: CONSULTATIONS, Length: 11508, dtype: object

# %% [markdown]
# yahooo, we got it.
# - as we saw above we have all consultations without null values
# - each patient differ others the number of consultations

# %% [markdown]
# After we applied mask, all null values are ignored. Let's now extract request and reply date time.

# %% [markdown]
# Wait wait, do you think we have request date time without reply data time?
#
# May be, remmber this question we will come back?

# %%
type(series_consult_without_null_vals[1])
# Out:
# str

# %% [markdown]
# As we saw above each value in the consultation feature (column) as text (string) str refer to string. We should covert text (string) to list to split each single consultation seperatly.

# %% [markdown]
# let's convert text (string) to list

# %% [markdown]
# ### first way

# %%
dict_consult = {i:s.split(';') for i, s in series_consult_without_null_vals.items() }
dict_consult
# Out:
# {1: ['Request:01-01-2021 23:38 Reply:02-01-2021 00:36'],
#  6: ['Request:02-01-2021 00:40 Reply:02-01-2021 01:21',
#   'Request:02-01-2021 00:49 Reply:02-01-2021 01:30'],
#  7: ['Request:02-01-2021 00:49 Reply:02-01-2021 01:39'],
#  8: ['Request:02-01-2021 03:24 Reply:02-01-2021 04:06'],
#  11: ['Request:01-01-2021 23:46 Reply:02-01-2021 00:29'],
#  12: ['Request:01-01-2021 21:11 Reply:01-01-2021 22:31'],
#  13: ['Request:01-01-2021 21:32 Reply:01-01-2021 22:39'],
#  14: ['Request:01-01-2021 22:35 Reply:01-01-2021 23:51'],
#  15: ['Request:01-01-2021 21:49 Reply:01-01-2021 23:14'],
#  16: ['Request:02-01-2021 02:33 Reply:02-01-2021 03:07'],
#  17: ['Request:01-01-2021 21:41 Reply:01-01-2021 22:47'],
#  19: ['Request:01-01-2021 17:51 Reply:01-01-2021 19:12'],
#  20: ['Request:01-01-2021 16:56 Reply:01-01-2021 17:46'],
#  22: ['Request:01-01-2021 19:05 Reply:01-01-2021 19:51'],
#  24: ['Request:01-01-2021 18:25 Reply:01-01-2021 23:17',
#   'Request:01-01-2021 21:22 Reply:01-01-2021 22:15'],
#  25: ['Request:01-01-2021 20:04 Reply:01-01-2021 21:36'],
#  27: ['Request:01-01-2021 19:44 Reply:17-01-2021 11:45',
#   'Request:01-01-2021 20:45 Reply:01-01-2021 21:58'],
#  28: ['Request:01-01-2021 18:58 Reply:02-01-2021 03:33'],
#  31: ['Request:01-01-2021 21:27 Reply:01-01-2021 22:12',
#   'Request:01-01-2021 21:28 Reply:'],
#  32: ['Request:01-01-2021 19:41 Reply:'],
#  35: ['Request:01-01-2021 19:06 Reply:01-01-2021 21:47'],
#  36: ['Request:01-01-2021 21:30 Reply:01-01-2021 21:57'],
#  38: ['Request:01-01-2021 19:27 Reply:01-01-2021 20:14'],
#  39: ['Request:01-01-2021 19:16 Reply:'],
#  40: ['Request:01-01-2021 19:31 Reply:01-01-2021 21:24'],
#  44: ['Request:01-01-2021 22:02 Reply:01-01-2021 23:29'],
#  46: ['Request:01-01-2021 19:37 Reply:01-01-2021 21:37'],
#  47: ['Request:01-01-2021 21:27 Reply:02-01-2021 00:53'],
#  53: ['Request:01-01-2021 21:59 Reply:'],
#  56: ['Request:01-01-2021 20:31 Reply:'],
#  57: ['Request:01-01-2021 19:13 Reply:01-01-2021 19:23'],
#  59: ['Request:01-01-2021 18:01 Reply:01-01-2021 19:01'],
#  63: ['Request:02-01-2021 00:13 Reply:02-01-2021 01:09'],
#  65: ['Request:01-01-2021 22:55 Reply:01-01-2021 23:42'],
#  68: ['Request:02-01-2021 01:59 Reply:02-01-2021 02:38'],
#  69: ['Request:01-01-2021 23:18 Reply:02-01-2021 01:23',
#   'Request:02-01-2021 00:26 Reply:02-01-2021 01:05'],
#  76: ['Request:01-01-2021 13:16 Reply:01-01-2021 14:42'],
#  79: ['Request:01-01-2021 13:28 Reply:01-01-2021 13:39'],
#  80: ['Request:01-01-2021 16:10 Reply:'],
#  81: ['Request:01-01-2021 14:31 Reply:01-01-2021 14:47'],
#  82: ['Request:01-01-2021 16:34 Reply:01-01-2021 18:58'],
#  87: ['Request:01-01-2021 15:37 Reply:01-01-2021 17:49'],
#  92: ['Request:01-01-2021 15:10 Reply:01-01-2021 15:25'],
#  97: ['Request:01-01-2021 16:16 Reply:'],
#  98: ['Request:01-01-2021 17:37 Reply:01-01-2021 18:58'],
#  99: ['Request:01-01-2021 15:25 Reply:01-01-2021 16:10'],
#  104: ['Request:01-01-2021 17:26 Reply:01-01-2021 17:45'],
#  105: ['Request:01-01-2021 17:12 Reply:01-01-2021 18:53',
#   'Request:01-01-2021 17:31 Reply:',
#   'Request:01-01-2021 17:55 Reply:01-01-2021 19:29'],
#  107: ['Request:01-01-2021 16:07 Reply:01-01-2021 16:34'],
#  109: ['Request:01-01-2021 17:54 Reply:01-01-2021 18:45'],
#  110: ['Request:01-01-2021 19:17 Reply:01-01-2021 20:13'],
#  111: ['Request:01-01-2021 20:16 Reply:02-01-2021 01:47',
#   'Request:01-01-2021 20:20 Reply:01-01-2021 20:53'],
#  114: ['Request:01-01-2021 17:59 Reply:01-01-2021 18:36'],
#  115: ['Request:01-01-2021 18:19 Reply:01-01-2021 19:00'],
#  121: ['Request:01-01-2021 20:26 Reply:01-01-2021 20:37'],
#  123: ['Request:01-01-2021 21:57 Reply:01-01-2021 23:03'],
#  124: ['Request:01-01-2021 21:35 Reply:01-01-2021 23:05'],
#  125: ['Request:01-01-2021 20:47 Reply:01-01-2021 23:32'],
#  126: ['Request:01-01-2021 22:00 Reply:01-01-2021 22:41'],
#  127: ['Request:01-01-2021 23:32 Reply:02-01-2021 00:19'],
#  128: ['Request:01-01-2021 21:39 Reply:02-01-2021 04:34',
#   'Request:01-01-2021 22:36 Reply:02-01-2021 04:16'],
#  130: ['Request:01-01-2021 22:07 Reply:01-01-2021 22:41'],
#  131: ['Request:01-01-2021 22:21 Reply:02-01-2021 01:47'],
#  132: ['Request:01-01-2021 22:05 Reply:01-01-2021 22:16'],
#  133: ['Request:01-01-2021 21:44 Reply:01-01-2021 23:11'],
#  135: ['Request:01-01-2021 22:04 Reply:01-01-2021 22:26'],
#  136: ['Request:01-01-2021 23:32 Reply:02-01-2021 01:24'],
#  137: ['Request:01-01-2021 22:37 Reply:01-01-2021 23:54'],
#  140: ['Request:01-01-2021 22:17 Reply:02-01-2021 03:27'],
#  141: ['Request:02-01-2021 00:08 Reply:02-01-2021 00:43'],
#  144: ['Request:01-01-2021 23:06 Reply:02-01-2021 00:04'],
#  146: ['Request:01-01-2021 22:40 Reply:01-01-2021 23:45'],
#  147: ['Request:01-01-2021 22:52 Reply:02-01-2021 00:24'],
#  148: ['Request:01-01-2021 23:40 Reply:02-01-2021 01:35',
#   'Request:02-01-2021 03:01 Reply:02-01-2021 03:10'],
#  149: ['Request:01-01-2021 23:35 Reply:02-01-2021 01:34'],
#  150: ['Request:01-01-2021 23:00 Reply:01-01-2021 23:35'],
#  153: ['Request:01-01-2021 03:43 Reply:01-01-2021 06:36'],
#  155: ['Request:01-01-2021 05:05 Reply:01-01-2021 05:06'],
#  157: ['Request:01-01-2021 02:01 Reply:01-01-2021 03:03'],
#  159: ['Request:01-01-2021 03:13 Reply:01-01-2021 03:25'],
#  160: ['Request:01-01-2021 02:46 Reply:01-01-2021 03:02',
#   'Request:01-01-2021 02:49 Reply:01-01-2021 06:13'],
#  164: ['Request:01-01-2021 02:28 Reply:01-01-2021 03:11'],
#  165: ['Request:01-01-2021 02:30 Reply:01-01-2021 04:21'],
#  166: ['Request:01-01-2021 03:49 Reply:01-01-2021 06:36'],
#  167: ['Request:01-01-2021 02:22 Reply:01-01-2021 03:09'],
#  169: ['Request:01-01-2021 05:52 Reply:01-01-2021 07:22'],
#  170: ['Request:01-01-2021 06:06 Reply:01-01-2021 06:26'],
#  174: ['Request:01-01-2021 09:05 Reply:01-01-2021 09:38'],
#  176: ['Request:01-01-2021 14:37 Reply:'],
#  178: ['Request:01-01-2021 03:21 Reply:01-01-2021 04:26',
#   'Request:01-01-2021 04:14 Reply:01-01-2021 07:55',
#   'Request:01-01-2021 04:16 Reply:01-01-2021 06:47',
#   'Request:01-01-2021 04:24 Reply:01-01-2021 05:11',
#   'Request:01-01-2021 04:29 Reply:',
#   'Request:01-01-2021 05:07 Reply:'],
#  182: ['Request:01-01-2021 08:47 Reply:01-01-2021 09:04'],
#  184: ['Request:01-01-2021 09:29 Reply:01-01-2021 10:34'],
#  185: ['Request:01-01-2021 08:52 Reply:01-01-2021 10:03'],
#  195: ['Request:01-01-2021 10:14 Reply:01-01-2021 15:12'],
#  202: ['Request:01-01-2021 09:21 Reply:01-01-2021 10:15'],
#  203: ['Request:01-01-2021 09:13 Reply:01-01-2021 09:50'],
#  204: ['Request:01-01-2021 10:56 Reply:01-01-2021 11:15'],
#  205: ['Request:01-01-2021 03:59 Reply:01-01-2021 04:19'],
#  206: ['Request:01-01-2021 04:13 Reply:01-01-2021 06:35'],
#  215: ['Request:01-01-2021 03:46 Reply:01-01-2021 03:52'],
#  216: ['Request:01-01-2021 04:35 Reply:01-01-2021 06:06',
#   'Request:01-01-2021 05:07 Reply:'],
#  219: ['Request:01-01-2021 10:06 Reply:02-01-2021 01:27',
#   'Request:01-01-2021 10:09 Reply:01-01-2021 10:32'],
#  220: ['Request:01-01-2021 09:31 Reply:01-01-2021 10:24'],
#  221: ['Request:01-01-2021 10:53 Reply:01-01-2021 11:50'],
#  225: ['Request:01-01-2021 10:50 Reply:01-01-2021 11:40'],
#  226: ['Request:01-01-2021 13:19 Reply:01-01-2021 14:34'],
#  228: ['Request:01-01-2021 13:36 Reply:'],
#  229: ['Request:01-01-2021 11:01 Reply:01-01-2021 14:06'],
#  235: ['Request:01-01-2021 05:12 Reply:01-01-2021 05:38'],
#  237: ['Request:01-01-2021 04:56 Reply:01-01-2021 05:21'],
#  239: ['Request:01-01-2021 06:06 Reply:01-01-2021 07:32'],
#  240: ['Request:01-01-2021 05:52 Reply:01-01-2021 08:41'],
#  246: ['Request:01-01-2021 05:37 Reply:'],
#  247: ['Request:01-01-2021 07:06 Reply:01-01-2021 07:27'],
#  250: ['Request:01-01-2021 06:40 Reply:01-01-2021 08:04'],
#  251: ['Request:01-01-2021 13:00 Reply:01-01-2021 13:17'],
#  253: ['Request:01-01-2021 11:22 Reply:01-01-2021 11:57'],
#  256: ['Request:01-01-2021 14:05 Reply:01-01-2021 14:56'],
#  260: ['Request:01-01-2021 03:38 Reply:01-01-2021 06:37'],
#  261: ['Request:01-01-2021 01:46 Reply:01-01-2021 02:44'],
#  267: ['Request:01-01-2021 00:58 Reply:01-01-2021 01:43'],
#  269: ['Request:01-01-2021 00:50 Reply:01-01-2021 01:09'],
#  270: ['Request:01-01-2021 01:05 Reply:01-01-2021 03:00'],
#  271: ['Request:01-01-2021 00:49 Reply:01-01-2021 01:23'],
#  274: ['Request:01-01-2021 01:01 Reply:01-01-2021 01:11'],
#  280: ['Request:01-01-2021 01:12 Reply:01-01-2021 01:47'],
#  285: ['Request:01-01-2021 01:27 Reply:01-01-2021 02:01'],
#  288: ['Request:02-01-2021 01:27 Reply:02-01-2021 01:39'],
#  289: ['Request:02-01-2021 03:50 Reply:02-01-2021 04:18'],
#  303: ['Request:02-01-2021 04:29 Reply:02-01-2021 04:35',
#   'Request:02-01-2021 04:32 Reply:02-01-2021 05:35'],
#  305: ['Request:02-01-2021 03:25 Reply:02-01-2021 05:21'],
#  306: ['Request:02-01-2021 03:04 Reply:02-01-2021 03:37'],
#  307: ['Request:02-01-2021 02:53 Reply:02-01-2021 03:26'],
#  313: ['Request:02-01-2021 02:21 Reply:02-01-2021 02:46'],
#  314: ['Request:02-01-2021 02:46 Reply:02-01-2021 04:03'],
#  315: ['Request:02-01-2021 02:02 Reply:02-01-2021 02:07'],
#  316: ['Request:02-01-2021 03:41 Reply:02-01-2021 04:25'],
#  317: ['Request:02-01-2021 03:35 Reply:02-01-2021 03:43',
#   'Request:02-01-2021 04:02 Reply:02-01-2021 04:51'],
#  319: ['Request:02-01-2021 00:51 Reply:02-01-2021 01:34'],
#  323: ['Request:02-01-2021 01:22 Reply:02-01-2021 02:08',
#   'Request:02-01-2021 02:48 Reply:02-01-2021 03:45'],
#  324: ['Request:02-01-2021 00:55 Reply:02-01-2021 03:21'],
#  327: ['Request:02-01-2021 17:32 Reply:'],
#  329: ['Request:02-01-2021 20:16 Reply:02-01-2021 22:58',
#   'Request:02-01-2021 23:24 Reply:03-01-2021 03:47'],
#  331: ['Request:02-01-2021 17:38 Reply:02-01-2021 21:05',
#   'Request:02-01-2021 18:13 Reply:02-01-2021 20:19',
#   'Request:02-01-2021 23:38 Reply:03-01-2021 00:42',
#   'Request:03-01-2021 01:06 Reply:03-01-2021 01:10'],
#  332: ['Request:02-01-2021 19:11 Reply:02-01-2021 19:28'],
#  335: ['Request:02-01-2021 13:50 Reply:02-01-2021 15:16'],
#  336: ['Request:02-01-2021 11:33 Reply:02-01-2021 13:13'],
#  340: ['Request:02-01-2021 13:28 Reply:02-01-2021 13:58'],
#  341: ['Request:02-01-2021 14:41 Reply:02-01-2021 15:50'],
#  342: ['Request:02-01-2021 16:59 Reply:02-01-2021 17:55'],
#  343: ['Request:02-01-2021 11:50 Reply:02-01-2021 12:17'],
#  346: ['Request:02-01-2021 12:39 Reply:02-01-2021 13:42'],
#  347: ['Request:02-01-2021 13:45 Reply:02-01-2021 13:50'],
#  349: ['Request:02-01-2021 14:25 Reply:02-01-2021 16:26'],
#  350: ['Request:02-01-2021 15:10 Reply:02-01-2021 16:53'],
#  352: ['Request:02-01-2021 20:29 Reply:02-01-2021 20:57',
#   'Request:02-01-2021 20:29 Reply:02-01-2021 21:22'],
#  353: ['Request:02-01-2021 21:36 Reply:02-01-2021 23:38'],
#  354: ['Request:02-01-2021 20:24 Reply:02-01-2021 20:29',
#   'Request:02-01-2021 20:24 Reply:02-01-2021 21:05',
#   'Request:02-01-2021 20:25 Reply:03-01-2021 09:22'],
#  357: ['Request:02-01-2021 22:17 Reply:02-01-2021 22:57'],
#  359: ['Request:02-01-2021 20:38 Reply:02-01-2021 22:39'],
#  360: ['Request:02-01-2021 20:36 Reply:02-01-2021 22:49'],
#  363: ['Request:02-01-2021 19:05 Reply:'],
#  368: ['Request:03-01-2021 01:10 Reply:03-01-2021 01:52'],
#  371: ['Request:02-01-2021 20:26 Reply:02-01-2021 20:44'],
#  372: ['Request:02-01-2021 20:40 Reply:02-01-2021 22:32'],
#  373: ['Request:02-01-2021 21:18 Reply:02-01-2021 23:22'],
#  374: ['Request:02-01-2021 21:11 Reply:'],
#  378: ['Request:02-01-2021 22:43 Reply:03-01-2021 01:47',
#   'Request:03-01-2021 02:02 Reply:03-01-2021 05:06'],
#  379: ['Request:02-01-2021 21:04 Reply:03-01-2021 00:14'],
#  380: ['Request:02-01-2021 21:07 Reply:02-01-2021 21:54'],
#  381: ['Request:02-01-2021 03:22 Reply:02-01-2021 03:41'],
#  384: ['Request:02-01-2021 03:39 Reply:02-01-2021 05:06',
#   'Request:02-01-2021 04:07 Reply:02-01-2021 12:20',
#   'Request:02-01-2021 05:19 Reply:02-01-2021 05:22',
#   'Request:02-01-2021 06:39 Reply:02-01-2021 09:34',
#   'Request:02-01-2021 09:12 Reply:02-01-2021 09:58'],
#  385: ['Request:02-01-2021 21:26 Reply:02-01-2021 21:40'],
#  387: ['Request:02-01-2021 21:49 Reply:'],
#  388: ['Request:02-01-2021 23:33 Reply:03-01-2021 03:57'],
#  389: ['Request:02-01-2021 22:18 Reply:03-01-2021 01:01',
#   'Request:03-01-2021 00:40 Reply:03-01-2021 03:47',
#   'Request:03-01-2021 00:42 Reply:03-01-2021 06:29',
#   'Request:03-01-2021 00:45 Reply:03-01-2021 01:16',
#   'Request:03-01-2021 01:01 Reply:03-01-2021 08:58',
#   'Request:03-01-2021 01:05 Reply:03-01-2021 04:04'],
#  390: ['Request:02-01-2021 21:21 Reply:'],
#  392: ['Request:02-01-2021 04:33 Reply:02-01-2021 07:57'],
#  397: ['Request:02-01-2021 04:01 Reply:02-01-2021 05:20'],
#  398: ['Request:02-01-2021 04:07 Reply:02-01-2021 05:52'],
#  399: ['Request:02-01-2021 04:12 Reply:02-01-2021 05:29'],
#  400: ['Request:02-01-2021 06:10 Reply:02-01-2021 06:54'],
#  401: ['Request:02-01-2021 04:06 Reply:02-01-2021 05:18'],
#  403: ['Request:02-01-2021 04:00 Reply:02-01-2021 04:32'],
#  404: ['Request:02-01-2021 04:20 Reply:02-01-2021 05:28'],
#  405: ['Request:02-01-2021 05:39 Reply:02-01-2021 06:15'],
#  406: ['Request:02-01-2021 04:08 Reply:02-01-2021 05:09'],
#  407: ['Request:02-01-2021 20:05 Reply:'],
#  409: ['Request:02-01-2021 18:42 Reply:02-01-2021 20:03'],
#  410: ['Request:02-01-2021 18:43 Reply:02-01-2021 19:57'],
#  411: ['Request:02-01-2021 18:24 Reply:02-01-2021 18:48'],
#  412: ['Request:02-01-2021 18:55 Reply:02-01-2021 20:15'],
#  413: ['Request:02-01-2021 20:02 Reply:02-01-2021 22:59'],
#  414: ['Request:02-01-2021 23:40 Reply:03-01-2021 00:19'],
#  416: ['Request:03-01-2021 01:32 Reply:03-01-2021 02:30'],
#  419: ['Request:02-01-2021 23:39 Reply:03-01-2021 01:48'],
#  420: ['Request:03-01-2021 01:25 Reply:03-01-2021 05:42',
#   'Request:03-01-2021 01:28 Reply:'],
#  422: ['Request:02-01-2021 22:15 Reply:02-01-2021 22:41'],
#  423: ['Request:02-01-2021 04:42 Reply:02-01-2021 05:10'],
#  425: ['Request:02-01-2021 05:30 Reply:02-01-2021 05:45'],
#  427: ['Request:02-01-2021 04:37 Reply:02-01-2021 05:07',
#   'Request:02-01-2021 05:21 Reply:02-01-2021 05:33',
#   'Request:02-01-2021 05:21 Reply:02-01-2021 05:33',
#   'Request:02-01-2021 05:47 Reply:',
#   'Request:02-01-2021 05:50 Reply:02-01-2021 06:16'],
#  429: ['Request:02-01-2021 17:33 Reply:02-01-2021 18:40'],
#  430: ['Request:02-01-2021 16:42 Reply:02-01-2021 17:36'],
#  431: ['Request:02-01-2021 17:29 Reply:',
#   'Request:02-01-2021 19:06 Reply:02-01-2021 23:00'],
#  432: ['Request:02-01-2021 17:30 Reply:02-01-2021 18:11'],
#  434: ['Request:02-01-2021 17:25 Reply:02-01-2021 17:52'],
#  435: ['Request:02-01-2021 08:09 Reply:02-01-2021 09:22',
#   'Request:02-01-2021 11:17 Reply:02-01-2021 12:21'],
#  436: ['Request:02-01-2021 05:44 Reply:02-01-2021 06:03'],
#  439: ['Request:02-01-2021 06:22 Reply:02-01-2021 12:49'],
#  441: ['Request:02-01-2021 07:33 Reply:02-01-2021 07:46',
#   'Request:02-01-2021 11:25 Reply:02-01-2021 14:08',
#   'Request:02-01-2021 11:27 Reply:'],
#  442: ['Request:02-01-2021 07:32 Reply:02-01-2021 07:43',
#   'Request:02-01-2021 11:23 Reply:',
#   'Request:02-01-2021 11:24 Reply:02-01-2021 12:39'],
#  444: ['Request:02-01-2021 06:56 Reply:02-01-2021 07:54'],
#  448: ['Request:02-01-2021 19:01 Reply:02-01-2021 20:14'],
#  449: ['Request:02-01-2021 18:54 Reply:02-01-2021 22:33'],
#  452: ['Request:02-01-2021 19:53 Reply:02-01-2021 21:04'],
#  453: ['Request:02-01-2021 21:27 Reply:02-01-2021 21:56',
#   'Request:02-01-2021 22:24 Reply:02-01-2021 22:54',
#   'Request:03-01-2021 01:49 Reply:03-01-2021 05:07'],
#  454: ['Request:02-01-2021 20:25 Reply:03-01-2021 01:03'],
#  457: ['Request:02-01-2021 19:26 Reply:02-01-2021 22:10'],
#  458: ['Request:02-01-2021 19:33 Reply:02-01-2021 20:24'],
#  459: ['Request:02-01-2021 19:53 Reply:02-01-2021 21:40'],
#  460: ['Request:02-01-2021 20:49 Reply:',
#   'Request:02-01-2021 22:36 Reply:02-01-2021 22:51'],
#  461: ['Request:02-01-2021 20:58 Reply:03-01-2021 01:46'],
#  462: ['Request:02-01-2021 19:29 Reply:03-01-2021 04:29'],
#  463: ['Request:02-01-2021 23:03 Reply:03-01-2021 02:28'],
#  464: ['Request:02-01-2021 20:29 Reply:02-01-2021 22:30'],
#  466: ['Request:02-01-2021 23:53 Reply:03-01-2021 02:27',
#   'Request:03-01-2021 00:57 Reply:03-01-2021 02:26'],
#  467: ['Request:03-01-2021 01:15 Reply:03-01-2021 03:28'],
#  468: ['Request:03-01-2021 01:14 Reply:03-01-2021 03:35',
#   'Request:03-01-2021 05:28 Reply:03-01-2021 05:43'],
#  469: ['Request:03-01-2021 00:45 Reply:03-01-2021 01:02'],
#  471: ['Request:02-01-2021 23:42 Reply:03-01-2021 00:14'],
#  473: ['Request:02-01-2021 23:32 Reply:03-01-2021 00:07'],
#  474: ['Request:03-01-2021 01:21 Reply:03-01-2021 02:30'],
#  477: ['Request:03-01-2021 00:21 Reply:'],
#  478: ['Request:03-01-2021 01:41 Reply:'],
#  479: ['Request:02-01-2021 23:02 Reply:02-01-2021 23:23'],
#  480: ['Request:03-01-2021 01:19 Reply:03-01-2021 02:17',
#   'Request:03-01-2021 07:31 Reply:03-01-2021 13:06',
#   'Request:03-01-2021 07:34 Reply:03-01-2021 07:40'],
#  481: ['Request:03-01-2021 01:13 Reply:03-01-2021 03:36'],
#  484: ['Request:02-01-2021 04:46 Reply:02-01-2021 05:08'],
#  487: ['Request:02-01-2021 04:52 Reply:02-01-2021 05:09'],
#  491: ['Request:02-01-2021 07:06 Reply:02-01-2021 07:49',
#   'Request:02-01-2021 11:09 Reply:02-01-2021 12:20'],
#  492: ['Request:02-01-2021 07:25 Reply:02-01-2021 09:23'],
#  494: ['Request:02-01-2021 10:31 Reply:02-01-2021 10:55',
#   'Request:02-01-2021 10:33 Reply:02-01-2021 15:03',
#   'Request:02-01-2021 11:01 Reply:02-01-2021 13:11',
#   'Request:02-01-2021 13:25 Reply:02-01-2021 19:45',
#   'Request:02-01-2021 13:26 Reply:'],
#  496: ['Request:02-01-2021 07:30 Reply:02-01-2021 07:53'],
#  497: ['Request:02-01-2021 06:28 Reply:02-01-2021 09:56'],
#  499: ['Request:02-01-2021 05:18 Reply:02-01-2021 12:46'],
#  502: ['Request:02-01-2021 14:31 Reply:02-01-2021 16:16'],
#  504: ['Request:02-01-2021 12:51 Reply:02-01-2021 13:46'],
#  506: ['Request:02-01-2021 15:06 Reply:02-01-2021 16:04'],
#  511: ['Request:02-01-2021 15:14 Reply:02-01-2021 16:16'],
#  512: ['Request:02-01-2021 16:04 Reply:02-01-2021 16:37',
#   'Request:02-01-2021 17:41 Reply:02-01-2021 17:47',
#   'Request:02-01-2021 17:58 Reply:02-01-2021 18:44'],
#  516: ['Request:02-01-2021 15:01 Reply:02-01-2021 17:14'],
#  517: ['Request:02-01-2021 15:36 Reply:02-01-2021 16:29'],
#  519: ['Request:02-01-2021 16:01 Reply:02-01-2021 18:23',
#   'Request:02-01-2021 16:42 Reply:02-01-2021 17:02'],
#  521: ['Request:02-01-2021 16:03 Reply:'],
#  523: ['Request:02-01-2021 15:25 Reply:02-01-2021 15:48'],
#  524: ['Request:02-01-2021 19:05 Reply:02-01-2021 21:04'],
#  527: ['Request:03-01-2021 01:43 Reply:03-01-2021 03:27'],
#  529: ['Request:02-01-2021 23:44 Reply:'],
#  530: ['Request:03-01-2021 00:20 Reply:03-01-2021 00:35'],
#  531: ['Request:02-01-2021 23:46 Reply:'],
#  533: ['Request:02-01-2021 23:55 Reply:03-01-2021 02:39'],
#  534: ['Request:03-01-2021 00:14 Reply:03-01-2021 00:30'],
#  537: ['Request:03-01-2021 00:17 Reply:'],
#  542: ['Request:02-01-2021 12:23 Reply:02-01-2021 15:49'],
#  543: ['Request:02-01-2021 16:41 Reply:02-01-2021 17:13'],
#  544: ['Request:02-01-2021 18:11 Reply:02-01-2021 18:44'],
#  547: ['Request:02-01-2021 18:03 Reply:02-01-2021 21:57'],
#  549: ['Request:02-01-2021 16:17 Reply:02-01-2021 18:39'],
#  555: ['Request:02-01-2021 14:49 Reply:02-01-2021 15:40'],
#  557: ['Request:02-01-2021 16:40 Reply:'],
#  560: ['Request:02-01-2021 15:27 Reply:02-01-2021 17:28'],
#  563: ['Request:02-01-2021 15:53 Reply:02-01-2021 20:42',
#   'Request:02-01-2021 16:13 Reply:02-01-2021 17:05'],
#  565: ['Request:02-01-2021 02:51 Reply:02-01-2021 03:43'],
#  566: ['Request:02-01-2021 02:41 Reply:02-01-2021 03:39'],
#  569: ['Request:03-01-2021 01:42 Reply:03-01-2021 02:54'],
#  571: ['Request:03-01-2021 00:22 Reply:03-01-2021 01:56'],
#  575: ['Request:02-01-2021 08:55 Reply:02-01-2021 09:33'],
#  579: ['Request:02-01-2021 09:33 Reply:02-01-2021 10:43',
#   'Request:02-01-2021 15:04 Reply:02-01-2021 15:33'],
#  586: ['Request:02-01-2021 16:54 Reply:02-01-2021 18:30'],
#  589: ['Request:02-01-2021 18:27 Reply:02-01-2021 19:43'],
#  596: ['Request:02-01-2021 18:15 Reply:02-01-2021 20:57',
#   'Request:02-01-2021 20:52 Reply:02-01-2021 22:56'],
#  599: ['Request:02-01-2021 19:22 Reply:',
#   'Request:02-01-2021 20:47 Reply:03-01-2021 01:46'],
#  602: ['Request:02-01-2021 02:53 Reply:02-01-2021 04:13'],
#  606: ['Request:02-01-2021 03:00 Reply:02-01-2021 04:29'],
#  609: ['Request:02-01-2021 12:40 Reply:02-01-2021 13:56'],
#  614: ['Request:02-01-2021 12:01 Reply:',
#   'Request:02-01-2021 12:34 Reply:02-01-2021 13:01',
#   'Request:02-01-2021 12:37 Reply:02-01-2021 15:48',
#   'Request:02-01-2021 13:33 Reply:05-01-2021 19:52'],
#  619: ['Request:02-01-2021 10:56 Reply:02-01-2021 11:44'],
#  622: ['Request:02-01-2021 18:41 Reply:02-01-2021 19:57'],
#  625: ['Request:02-01-2021 11:34 Reply:02-01-2021 11:50'],
#  627: ['Request:02-01-2021 11:31 Reply:02-01-2021 13:05'],
#  628: ['Request:02-01-2021 17:06 Reply:02-01-2021 18:44'],
#  629: ['Request:02-01-2021 22:31 Reply:03-01-2021 00:49'],
#  633: ['Request:03-01-2021 16:28 Reply:03-01-2021 17:09'],
#  635: ['Request:03-01-2021 18:43 Reply:03-01-2021 19:29',
#   'Request:03-01-2021 18:47 Reply:03-01-2021 20:34'],
#  639: ['Request:03-01-2021 19:54 Reply:03-01-2021 21:23'],
#  641: ['Request:03-01-2021 17:12 Reply:03-01-2021 17:44'],
#  643: ['Request:03-01-2021 17:41 Reply:03-01-2021 20:46',
#   'Request:03-01-2021 22:38 Reply:03-01-2021 23:22'],
#  644: ['Request:03-01-2021 19:20 Reply:03-01-2021 20:38'],
#  646: ['Request:03-01-2021 17:28 Reply:03-01-2021 19:28'],
#  649: ['Request:03-01-2021 17:21 Reply:03-01-2021 18:07',
#   'Request:03-01-2021 20:26 Reply:03-01-2021 20:58'],
#  652: ['Request:03-01-2021 21:55 Reply:03-01-2021 23:52'],
#  654: ['Request:03-01-2021 17:36 Reply:03-01-2021 18:04'],
#  656: ['Request:03-01-2021 22:43 Reply:03-01-2021 23:08'],
#  660: ['Request:03-01-2021 23:02 Reply:04-01-2021 00:15'],
#  662: ['Request:03-01-2021 18:43 Reply:03-01-2021 20:33'],
#  663: ['Request:03-01-2021 17:29 Reply:03-01-2021 18:39'],
#  665: ['Request:03-01-2021 15:38 Reply:03-01-2021 15:42'],
#  667: ['Request:03-01-2021 19:06 Reply:'],
#  668: ['Request:03-01-2021 17:42 Reply:03-01-2021 17:49',
#   'Request:03-01-2021 17:44 Reply:03-01-2021 19:34'],
#  670: ['Request:03-01-2021 19:12 Reply:03-01-2021 23:04'],
#  673: ['Request:03-01-2021 19:59 Reply:03-01-2021 20:28',
#   'Request:03-01-2021 20:32 Reply:03-01-2021 23:57'],
#  675: ['Request:03-01-2021 19:17 Reply:03-01-2021 21:00',
#   'Request:04-01-2021 00:01 Reply:04-01-2021 00:54',
#   'Request:04-01-2021 00:23 Reply:'],
#  679: ['Request:03-01-2021 20:43 Reply:03-01-2021 23:42',
#   'Request:03-01-2021 23:22 Reply:04-01-2021 00:28'],
#  682: ['Request:03-01-2021 19:27 Reply:03-01-2021 22:15'],
#  683: ['Request:03-01-2021 21:25 Reply:03-01-2021 22:23'],
#  684: ['Request:03-01-2021 19:26 Reply:03-01-2021 19:55'],
#  685: ['Request:03-01-2021 19:36 Reply:03-01-2021 20:55'],
#  688: ['Request:03-01-2021 21:16 Reply:03-01-2021 22:20'],
#  691: ['Request:03-01-2021 21:11 Reply:03-01-2021 23:48'],
#  698: ['Request:03-01-2021 21:58 Reply:03-01-2021 22:59'],
#  699: ['Request:03-01-2021 22:40 Reply:03-01-2021 23:39'],
#  700: ['Request:03-01-2021 23:48 Reply:04-01-2021 00:12'],
#  701: ['Request:03-01-2021 15:59 Reply:03-01-2021 17:22'],
#  706: ['Request:03-01-2021 18:10 Reply:03-01-2021 19:58'],
#  710: ['Request:03-01-2021 22:26 Reply:03-01-2021 23:42'],
#  712: ['Request:03-01-2021 21:40 Reply:04-01-2021 00:56'],
#  713: ['Request:03-01-2021 21:32 Reply:03-01-2021 22:02'],
#  714: ['Request:03-01-2021 21:49 Reply:03-01-2021 23:23',
#   'Request:03-01-2021 21:52 Reply:03-01-2021 22:16'],
#  715: ['Request:03-01-2021 20:35 Reply:03-01-2021 22:11'],
#  719: ['Request:03-01-2021 20:15 Reply:03-01-2021 22:51'],
#  720: ['Request:03-01-2021 21:12 Reply:04-01-2021 00:56',
#   'Request:04-01-2021 03:09 Reply:'],
#  721: ['Request:03-01-2021 22:47 Reply:04-01-2021 01:11'],
#  724: ['Request:03-01-2021 20:16 Reply:03-01-2021 22:50'],
#  730: ['Request:03-01-2021 21:45 Reply:03-01-2021 22:30'],
#  732: ['Request:03-01-2021 21:13 Reply:03-01-2021 23:34'],
#  735: ['Request:03-01-2021 23:31 Reply:04-01-2021 02:31'],
#  736: ['Request:03-01-2021 21:11 Reply:03-01-2021 22:27'],
#  740: ['Request:03-01-2021 10:17 Reply:03-01-2021 11:31',
#   'Request:03-01-2021 12:01 Reply:03-01-2021 12:56'],
#  741: ['Request:03-01-2021 11:55 Reply:03-01-2021 13:27'],
#  742: ['Request:03-01-2021 10:28 Reply:03-01-2021 11:27'],
#  743: ['Request:03-01-2021 10:46 Reply:03-01-2021 12:23',
#   'Request:03-01-2021 15:26 Reply:03-01-2021 15:57'],
#  744: ['Request:03-01-2021 10:20 Reply:'],
#  746: ['Request:03-01-2021 10:37 Reply:03-01-2021 12:01'],
#  748: ['Request:03-01-2021 11:19 Reply:03-01-2021 13:47'],
#  749: ['Request:03-01-2021 11:33 Reply:03-01-2021 12:50'],
#  751: ['Request:03-01-2021 12:32 Reply:03-01-2021 14:30'],
#  753: ['Request:03-01-2021 12:51 Reply:03-01-2021 13:06'],
#  755: ['Request:03-01-2021 16:03 Reply:'],
#  758: ['Request:03-01-2021 11:45 Reply:03-01-2021 12:47'],
#  760: ['Request:03-01-2021 12:52 Reply:03-01-2021 13:36'],
#  761: ['Request:03-01-2021 12:59 Reply:03-01-2021 13:16'],
#  762: ['Request:03-01-2021 11:38 Reply:03-01-2021 12:49'],
#  764: ['Request:03-01-2021 12:43 Reply:03-01-2021 13:40'],
#  767: ['Request:03-01-2021 15:46 Reply:03-01-2021 17:29'],
#  768: ['Request:03-01-2021 16:24 Reply:03-01-2021 17:22'],
#  773: ['Request:03-01-2021 18:12 Reply:03-01-2021 19:26',
#   'Request:03-01-2021 23:17 Reply:04-01-2021 00:09'],
#  779: ['Request:03-01-2021 22:05 Reply:'],
#  780: ['Request:04-01-2021 01:35 Reply:04-01-2021 01:46'],
#  784: ['Request:03-01-2021 22:18 Reply:'],
#  785: ['Request:04-01-2021 00:53 Reply:04-01-2021 02:45',
#   'Request:04-01-2021 03:46 Reply:04-01-2021 04:13'],
#  786: ['Request:03-01-2021 22:15 Reply:03-01-2021 23:48'],
#  787: ['Request:04-01-2021 01:38 Reply:04-01-2021 02:31'],
#  788: ['Request:03-01-2021 22:30 Reply:03-01-2021 23:47'],
#  789: ['Request:04-01-2021 03:27 Reply:'],
#  790: ['Request:03-01-2021 22:39 Reply:04-01-2021 00:00'],
#  791: ['Request:04-01-2021 01:30 Reply:04-01-2021 02:03',
#   'Request:04-01-2021 01:31 Reply:',
#   'Request:04-01-2021 01:33 Reply:04-01-2021 03:31'],
#  793: ['Request:03-01-2021 08:19 Reply:03-01-2021 10:59'],
#  794: ['Request:03-01-2021 10:14 Reply:03-01-2021 10:49'],
#  795: ['Request:03-01-2021 09:23 Reply:03-01-2021 10:16'],
#  796: ['Request:03-01-2021 09:41 Reply:03-01-2021 14:09',
#   'Request:03-01-2021 10:27 Reply:03-01-2021 11:26'],
#  797: ['Request:03-01-2021 11:08 Reply:'],
#  798: ['Request:03-01-2021 09:17 Reply:03-01-2021 09:53'],
#  800: ['Request:03-01-2021 10:30 Reply:03-01-2021 10:52',
#   'Request:03-01-2021 10:34 Reply:',
#   'Request:03-01-2021 19:50 Reply:04-01-2021 01:08',
#   'Request:04-01-2021 01:01 Reply:04-01-2021 06:53'],
#  811: ['Request:03-01-2021 09:53 Reply:03-01-2021 10:41'],
#  812: ['Request:03-01-2021 10:17 Reply:03-01-2021 11:27'],
#  814: ['Request:03-01-2021 01:33 Reply:03-01-2021 01:41'],
#  816: ['Request:03-01-2021 01:27 Reply:'],
#  817: ['Request:03-01-2021 04:20 Reply:03-01-2021 07:46'],
#  819: ['Request:03-01-2021 01:52 Reply:'],
#  820: ['Request:03-01-2021 01:47 Reply:03-01-2021 02:11'],
#  824: ['Request:03-01-2021 02:47 Reply:03-01-2021 03:38'],
#  831: ['Request:03-01-2021 08:25 Reply:03-01-2021 09:40'],
#  838: ['Request:03-01-2021 04:30 Reply:03-01-2021 08:18',
#   'Request:03-01-2021 08:49 Reply:03-01-2021 09:10'],
#  839: ['Request:03-01-2021 04:00 Reply:03-01-2021 04:15'],
#  841: ['Request:03-01-2021 05:37 Reply:03-01-2021 06:46'],
#  844: ['Request:03-01-2021 05:03 Reply:03-01-2021 05:43',
#   'Request:03-01-2021 05:42 Reply:03-01-2021 06:43'],
#  847: ['Request:03-01-2021 05:12 Reply:03-01-2021 06:32',
#   'Request:03-01-2021 05:19 Reply:03-01-2021 05:25'],
#  850: ['Request:03-01-2021 04:40 Reply:03-01-2021 05:57'],
#  858: ['Request:03-01-2021 15:09 Reply:03-01-2021 15:41'],
#  862: ['Request:03-01-2021 04:28 Reply:03-01-2021 05:04'],
#  863: ['Request:03-01-2021 00:36 Reply:03-01-2021 00:45'],
#  874: ['Request:03-01-2021 05:24 Reply:03-01-2021 05:47'],
#  875: ['Request:03-01-2021 01:55 Reply:'],
#  876: ['Request:03-01-2021 01:52 Reply:'],
#  879: ['Request:03-01-2021 02:52 Reply:03-01-2021 04:01'],
#  881: ['Request:03-01-2021 02:41 Reply:03-01-2021 04:03'],
#  882: ['Request:03-01-2021 01:47 Reply:03-01-2021 02:06'],
#  884: ['Request:03-01-2021 02:24 Reply:03-01-2021 02:44'],
#  885: ['Request:03-01-2021 07:55 Reply:03-01-2021 09:32',
#   'Request:03-01-2021 08:09 Reply:03-01-2021 09:33',
#   'Request:03-01-2021 09:39 Reply:03-01-2021 10:17'],
#  890: ['Request:03-01-2021 03:08 Reply:03-01-2021 03:08'],
#  896: ['Request:03-01-2021 13:37 Reply:03-01-2021 16:47'],
#  899: ['Request:03-01-2021 13:25 Reply:03-01-2021 15:04'],
#  900: ['Request:03-01-2021 13:30 Reply:'],
#  901: ['Request:03-01-2021 15:37 Reply:03-01-2021 16:10'],
#  905: ['Request:03-01-2021 04:48 Reply:03-01-2021 06:09'],
#  907: ['Request:03-01-2021 03:06 Reply:03-01-2021 03:22'],
#  910: ['Request:03-01-2021 02:56 Reply:03-01-2021 03:16'],
#  911: ['Request:03-01-2021 03:25 Reply:03-01-2021 05:41'],
#  915: ['Request:03-01-2021 04:33 Reply:03-01-2021 06:58'],
#  917: ['Request:03-01-2021 04:30 Reply:'],
#  920: ['Request:03-01-2021 22:42 Reply:'],
#  922: ['Request:04-01-2021 02:00 Reply:04-01-2021 03:56'],
#  925: ['Request:04-01-2021 03:26 Reply:'],
#  926: ['Request:04-01-2021 03:17 Reply:04-01-2021 03:47',
#   'Request:04-01-2021 05:56 Reply:04-01-2021 08:05'],
#  929: ['Request:03-01-2021 23:25 Reply:04-01-2021 00:45'],
#  930: ['Request:03-01-2021 23:21 Reply:04-01-2021 01:47'],
#  932: ['Request:03-01-2021 16:44 Reply:03-01-2021 19:22'],
#  934: ['Request:03-01-2021 19:00 Reply:03-01-2021 22:17',
#   'Request:03-01-2021 21:21 Reply:03-01-2021 22:05'],
#  936: ['Request:03-01-2021 18:39 Reply:03-01-2021 19:54'],
#  937: ['Request:03-01-2021 15:57 Reply:03-01-2021 17:07'],
#  940: ['Request:03-01-2021 16:29 Reply:03-01-2021 18:13'],
#  942: ['Request:03-01-2021 12:27 Reply:03-01-2021 12:37'],
#  943: ['Request:03-01-2021 13:52 Reply:03-01-2021 15:29'],
#  946: ['Request:03-01-2021 13:37 Reply:03-01-2021 14:58'],
#  952: ['Request:03-01-2021 14:55 Reply:03-01-2021 15:07',
#   'Request:03-01-2021 16:29 Reply:'],
#  954: ['Request:03-01-2021 14:38 Reply:03-01-2021 16:56'],
#  955: ['Request:03-01-2021 23:48 Reply:04-01-2021 00:32'],
#  958: ['Request:03-01-2021 23:28 Reply:03-01-2021 23:47'],
#  960: ['Request:04-01-2021 00:23 Reply:04-01-2021 01:40'],
#  964: ['Request:03-01-2021 10:19 Reply:03-01-2021 11:05'],
#  970: ['Request:03-01-2021 14:15 Reply:17-01-2021 11:45'],
#  978: ['Request:04-01-2021 11:10 Reply:04-01-2021 13:42',
#   'Request:04-01-2021 12:50 Reply:04-01-2021 13:07',
#   'Request:04-01-2021 12:52 Reply:04-01-2021 15:57'],
#  979: ['Request:04-01-2021 12:37 Reply:04-01-2021 14:41',
#   'Request:04-01-2021 12:39 Reply:04-01-2021 13:36'],
#  983: ['Request:04-01-2021 11:04 Reply:04-01-2021 12:05'],
#  985: ['Request:04-01-2021 12:23 Reply:04-01-2021 13:09'],
#  986: ['Request:04-01-2021 10:45 Reply:04-01-2021 10:56'],
#  987: ['Request:04-01-2021 12:07 Reply:04-01-2021 13:18'],
#  989: ['Request:04-01-2021 12:21 Reply:04-01-2021 13:13'],
#  991: ['Request:04-01-2021 17:15 Reply:04-01-2021 19:46'],
#  994: ['Request:04-01-2021 14:24 Reply:04-01-2021 14:27'],
#  996: ['Request:04-01-2021 06:30 Reply:04-01-2021 07:55'],
#  998: ['Request:04-01-2021 04:21 Reply:04-01-2021 07:38'],
#  1001: ['Request:04-01-2021 05:12 Reply:'],
#  1003: ['Request:04-01-2021 15:34 Reply:04-01-2021 15:48'],
#  1006: ['Request:04-01-2021 18:18 Reply:'],
#  1009: ['Request:04-01-2021 15:47 Reply:04-01-2021 17:06'],
#  1010: ['Request:04-01-2021 16:20 Reply:04-01-2021 18:24'],
#  1011: ['Request:04-01-2021 17:21 Reply:04-01-2021 18:34'],
#  1012: ['Request:04-01-2021 16:04 Reply:04-01-2021 17:02'],
#  1013: ['Request:04-01-2021 16:32 Reply:04-01-2021 18:21'],
#  1015: ['Request:04-01-2021 20:20 Reply:04-01-2021 23:11',
#   'Request:04-01-2021 22:48 Reply:05-01-2021 00:46'],
#  1016: ['Request:04-01-2021 16:51 Reply:04-01-2021 17:39'],
#  1017: ['Request:04-01-2021 19:36 Reply:'],
#  1020: ['Request:04-01-2021 13:14 Reply:04-01-2021 14:05',
#   'Request:04-01-2021 15:17 Reply:04-01-2021 15:57'],
#  1024: ['Request:04-01-2021 05:22 Reply:04-01-2021 06:16'],
#  1025: ['Request:04-01-2021 05:51 Reply:04-01-2021 08:34'],
#  1026: ['Request:04-01-2021 06:15 Reply:04-01-2021 06:56'],
#  1028: ['Request:04-01-2021 07:05 Reply:04-01-2021 08:39'],
#  1029: ['Request:04-01-2021 08:27 Reply:05-01-2021 00:09'],
#  1030: ['Request:04-01-2021 10:40 Reply:04-01-2021 13:07',
#   'Request:04-01-2021 12:53 Reply:04-01-2021 16:27'],
#  1031: ['Request:04-01-2021 07:00 Reply:04-01-2021 08:30'],
#  1035: ['Request:04-01-2021 17:36 Reply:04-01-2021 18:20'],
#  1036: ['Request:04-01-2021 20:22 Reply:04-01-2021 22:16'],
#  1037: ['Request:04-01-2021 20:18 Reply:05-01-2021 00:01'],
#  1038: ['Request:04-01-2021 20:30 Reply:05-01-2021 00:00'],
#  1041: ['Request:04-01-2021 18:26 Reply:04-01-2021 21:23'],
#  1042: ['Request:04-01-2021 17:52 Reply:05-01-2021 00:03',
#   'Request:04-01-2021 18:37 Reply:',
#   'Request:04-01-2021 20:24 Reply:04-01-2021 20:58',
#   'Request:04-01-2021 20:29 Reply:04-01-2021 22:53'],
#  1046: ['Request:04-01-2021 15:12 Reply:04-01-2021 15:25'],
#  1047: ['Request:04-01-2021 20:45 Reply:04-01-2021 22:16'],
#  1048: ['Request:04-01-2021 18:31 Reply:04-01-2021 18:48'],
#  1049: ['Request:04-01-2021 21:19 Reply:04-01-2021 22:57'],
#  1050: ['Request:04-01-2021 18:58 Reply:04-01-2021 19:59'],
#  1052: ['Request:04-01-2021 18:40 Reply:04-01-2021 20:21'],
#  1057: ['Request:04-01-2021 14:59 Reply:17-01-2021 11:45'],
#  1058: ['Request:04-01-2021 17:13 Reply:04-01-2021 20:59'],
#  1060: ['Request:04-01-2021 19:37 Reply:05-01-2021 00:39'],
#  1069: ['Request:04-01-2021 04:41 Reply:'],
#  1070: ['Request:04-01-2021 04:23 Reply:04-01-2021 07:36'],
#  1071: ['Request:04-01-2021 17:26 Reply:'],
#  1075: ['Request:04-01-2021 22:54 Reply:05-01-2021 00:38'],
#  1077: ['Request:04-01-2021 17:45 Reply:04-01-2021 19:01',
#   'Request:04-01-2021 18:44 Reply:05-01-2021 19:46'],
#  1079: ['Request:04-01-2021 18:10 Reply:04-01-2021 18:24'],
#  1081: ['Request:04-01-2021 09:14 Reply:04-01-2021 10:06'],
#  1085: ['Request:04-01-2021 15:13 Reply:04-01-2021 16:04'],
#  1091: ['Request:04-01-2021 01:56 Reply:04-01-2021 03:49'],
#  1094: ['Request:04-01-2021 02:49 Reply:'],
#  1098: ['Request:04-01-2021 13:11 Reply:04-01-2021 14:46'],
#  1099: ['Request:04-01-2021 13:44 Reply:04-01-2021 14:28'],
#  1100: ['Request:04-01-2021 14:59 Reply:04-01-2021 15:09',
#   'Request:04-01-2021 16:06 Reply:04-01-2021 19:07'],
#  1101: ['Request:04-01-2021 12:21 Reply:04-01-2021 17:01',
#   'Request:04-01-2021 12:24 Reply:04-01-2021 17:22',
#   'Request:04-01-2021 12:25 Reply:04-01-2021 12:56',
#   'Request:04-01-2021 12:25 Reply:04-01-2021 12:43'],
#  1102: ['Request:04-01-2021 12:58 Reply:04-01-2021 13:15'],
#  1103: ['Request:04-01-2021 21:49 Reply:05-01-2021 01:40'],
#  1105: ['Request:04-01-2021 22:53 Reply:05-01-2021 02:11',
#   'Request:05-01-2021 01:06 Reply:05-01-2021 02:05'],
#  1110: ['Request:04-01-2021 20:30 Reply:04-01-2021 21:50'],
#  1115: ['Request:04-01-2021 20:43 Reply:05-01-2021 00:47'],
#  1116: ['Request:04-01-2021 21:06 Reply:04-01-2021 22:26'],
#  1117: ['Request:04-01-2021 22:57 Reply:05-01-2021 00:31',
#   'Request:05-01-2021 01:18 Reply:05-01-2021 03:18'],
#  1118: ['Request:05-01-2021 01:22 Reply:05-01-2021 02:06'],
#  1119: ['Request:04-01-2021 03:48 Reply:04-01-2021 07:45'],
#  1120: ['Request:04-01-2021 03:15 Reply:04-01-2021 03:43'],
#  1125: ['Request:04-01-2021 02:28 Reply:04-01-2021 03:29'],
#  1126: ['Request:04-01-2021 05:24 Reply:04-01-2021 06:12',
#   'Request:04-01-2021 09:42 Reply:04-01-2021 10:48',
#   'Request:04-01-2021 10:27 Reply:04-01-2021 11:33'],
#  1127: ['Request:04-01-2021 03:05 Reply:',
#   'Request:04-01-2021 03:05 Reply:04-01-2021 03:29'],
#  1128: ['Request:04-01-2021 21:41 Reply:04-01-2021 23:56',
#   'Request:04-01-2021 23:48 Reply:',
#   'Request:05-01-2021 09:33 Reply:05-01-2021 09:48',
#   'Request:05-01-2021 09:45 Reply:05-01-2021 10:08'],
#  1130: ['Request:04-01-2021 21:30 Reply:04-01-2021 22:49'],
#  1134: ['Request:04-01-2021 02:46 Reply:04-01-2021 03:48'],
#  1137: ['Request:04-01-2021 01:02 Reply:04-01-2021 01:41'],
#  1139: ['Request:04-01-2021 02:51 Reply:04-01-2021 07:39'],
#  1143: ['Request:04-01-2021 01:04 Reply:04-01-2021 03:52'],
#  1144: ['Request:04-01-2021 03:21 Reply:04-01-2021 04:29'],
#  1146: ['Request:04-01-2021 03:02 Reply:04-01-2021 03:29'],
#  1148: ['Request:04-01-2021 04:27 Reply:'],
#  1150: ['Request:04-01-2021 05:54 Reply:04-01-2021 06:58'],
#  1151: ['Request:04-01-2021 03:37 Reply:04-01-2021 04:31'],
#  1154: ['Request:04-01-2021 09:08 Reply:05-01-2021 00:08'],
#  1161: ['Request:04-01-2021 11:29 Reply:04-01-2021 11:36',
#   'Request:04-01-2021 12:37 Reply:04-01-2021 14:48'],
#  1164: ['Request:04-01-2021 13:42 Reply:05-01-2021 00:06'],
#  1166: ['Request:04-01-2021 14:44 Reply:04-01-2021 15:28'],
#  1167: ['Request:04-01-2021 13:29 Reply:04-01-2021 14:29'],
#  1168: ['Request:04-01-2021 13:40 Reply:04-01-2021 15:37'],
#  1171: ['Request:04-01-2021 17:19 Reply:04-01-2021 18:49'],
#  1175: ['Request:04-01-2021 16:09 Reply:05-01-2021 00:05',
#   'Request:04-01-2021 22:43 Reply:04-01-2021 23:19'],
#  1177: ['Request:04-01-2021 17:47 Reply:05-01-2021 00:03'],
#  1179: ['Request:04-01-2021 14:35 Reply:04-01-2021 15:05',
#   'Request:04-01-2021 14:53 Reply:04-01-2021 16:09'],
#  1182: ['Request:04-01-2021 11:28 Reply:04-01-2021 14:48'],
#  1186: ['Request:04-01-2021 11:08 Reply:04-01-2021 12:52'],
#  1187: ['Request:04-01-2021 11:07 Reply:04-01-2021 12:48'],
#  1191: ['Request:04-01-2021 08:54 Reply:05-01-2021 05:13'],
#  1194: ['Request:04-01-2021 09:26 Reply:04-01-2021 10:03'],
#  1199: ['Request:04-01-2021 20:28 Reply:04-01-2021 20:55'],
#  1202: ['Request:04-01-2021 04:15 Reply:04-01-2021 05:18',
#   'Request:04-01-2021 04:25 Reply:04-01-2021 06:57'],
#  1203: ['Request:04-01-2021 05:58 Reply:04-01-2021 06:22'],
#  1204: ['Request:04-01-2021 06:16 Reply:04-01-2021 07:40'],
#  1205: ['Request:04-01-2021 04:57 Reply:'],
#  1209: ['Request:04-01-2021 04:51 Reply:04-01-2021 08:36'],
#  1212: ['Request:04-01-2021 07:38 Reply:04-01-2021 08:20'],
#  1213: ['Request:04-01-2021 08:12 Reply:', 'Request:04-01-2021 09:03 Reply:'],
#  1215: ['Request:04-01-2021 09:27 Reply:04-01-2021 11:02'],
#  1219: ['Request:04-01-2021 10:42 Reply:04-01-2021 14:18'],
#  1220: ['Request:04-01-2021 10:37 Reply:04-01-2021 10:54'],
#  1223: ['Request:04-01-2021 16:50 Reply:04-01-2021 17:43'],
#  1224: ['Request:04-01-2021 14:43 Reply:04-01-2021 16:43'],
#  1228: ['Request:04-01-2021 17:24 Reply:'],
#  1230: ['Request:04-01-2021 20:33 Reply:05-01-2021 00:28'],
#  1234: ['Request:05-01-2021 01:14 Reply:05-01-2021 01:27',
#   'Request:05-01-2021 01:31 Reply:05-01-2021 02:09'],
#  1239: ['Request:04-01-2021 23:47 Reply:05-01-2021 01:54'],
#  1241: ['Request:04-01-2021 21:35 Reply:04-01-2021 22:47'],
#  1243: ['Request:04-01-2021 22:10 Reply:'],
#  1244: ['Request:04-01-2021 22:12 Reply:04-01-2021 23:54'],
#  1245: ['Request:04-01-2021 23:42 Reply:05-01-2021 01:33',
#   'Request:05-01-2021 01:44 Reply:05-01-2021 06:14'],
#  1246: ['Request:04-01-2021 22:06 Reply:04-01-2021 22:31'],
#  1247: ['Request:04-01-2021 23:27 Reply:05-01-2021 00:01'],
#  1248: ['Request:05-01-2021 00:28 Reply:05-01-2021 00:38'],
#  1255: ['Request:04-01-2021 22:39 Reply:'],
#  1257: ['Request:04-01-2021 22:48 Reply:04-01-2021 23:12'],
#  1259: ['Request:04-01-2021 23:19 Reply:04-01-2021 23:38'],
#  1260: ['Request:05-01-2021 00:06 Reply:05-01-2021 00:45'],
#  1261: ['Request:05-01-2021 04:23 Reply:05-01-2021 07:11',
#   'Request:05-01-2021 05:41 Reply:05-01-2021 07:34',
#   'Request:05-01-2021 10:42 Reply:06-01-2021 04:44'],
#  1266: ['Request:04-01-2021 23:19 Reply:04-01-2021 23:50'],
#  1268: ['Request:04-01-2021 23:31 Reply:05-01-2021 00:45'],
#  1270: ['Request:04-01-2021 23:47 Reply:05-01-2021 00:08'],
#  1272: ['Request:05-01-2021 00:28 Reply:05-01-2021 01:16'],
#  1273: ['Request:05-01-2021 00:10 Reply:05-01-2021 00:56'],
#  1274: ['Request:04-01-2021 23:47 Reply:05-01-2021 00:15',
#   'Request:05-01-2021 00:39 Reply:05-01-2021 02:11'],
#  1278: ['Request:05-01-2021 00:21 Reply:05-01-2021 02:34',
#   'Request:05-01-2021 00:50 Reply:05-01-2021 01:09'],
#  1280: ['Request:05-01-2021 00:14 Reply:05-01-2021 01:03'],
#  1282: ['Request:05-01-2021 00:26 Reply:05-01-2021 02:34'],
#  1285: ['Request:05-01-2021 00:08 Reply:05-01-2021 00:42'],
#  1291: ['Request:04-01-2021 21:34 Reply:04-01-2021 23:17'],
#  1292: ['Request:05-01-2021 02:17 Reply:05-01-2021 02:26'],
#  1293: ['Request:04-01-2021 21:08 Reply:05-01-2021 01:00'],
#  1297: ['Request:04-01-2021 22:05 Reply:04-01-2021 22:22'],
#  1300: ['Request:04-01-2021 23:19 Reply:05-01-2021 01:26'],
#  1301: ['Request:05-01-2021 21:41 Reply:05-01-2021 22:06'],
#  1307: ['Request:05-01-2021 23:54 Reply:06-01-2021 00:19'],
#  1308: ['Request:05-01-2021 22:44 Reply:06-01-2021 07:48',
#   'Request:05-01-2021 23:36 Reply:06-01-2021 01:31'],
#  1311: ['Request:06-01-2021 02:15 Reply:06-01-2021 06:56',
#   'Request:06-01-2021 02:53 Reply:06-01-2021 06:25'],
#  1312: ['Request:06-01-2021 00:12 Reply:06-01-2021 01:29'],
#  1315: ['Request:06-01-2021 00:13 Reply:06-01-2021 00:35'],
#  1319: ['Request:06-01-2021 01:57 Reply:06-01-2021 03:19'],
#  1321: ['Request:05-01-2021 23:00 Reply:06-01-2021 00:36'],
#  1322: ['Request:06-01-2021 00:46 Reply:'],
#  1323: ['Request:06-01-2021 03:03 Reply:',
#   'Request:06-01-2021 06:28 Reply:06-01-2021 07:47'],
#  1324: ['Request:06-01-2021 01:44 Reply:06-01-2021 03:31'],
#  1325: ['Request:06-01-2021 01:23 Reply:06-01-2021 07:49'],
#  1327: ['Request:05-01-2021 21:25 Reply:05-01-2021 21:44'],
#  1328: ['Request:05-01-2021 23:33 Reply:06-01-2021 01:09'],
#  1340: ['Request:06-01-2021 01:54 Reply:06-01-2021 05:58'],
#  1343: ['Request:06-01-2021 01:26 Reply:06-01-2021 07:49'],
#  1351: ['Request:06-01-2021 00:27 Reply:06-01-2021 01:13'],
#  1355: ['Request:05-01-2021 00:43 Reply:05-01-2021 00:47'],
#  1356: ['Request:05-01-2021 02:06 Reply:05-01-2021 02:22'],
#  1358: ['Request:05-01-2021 02:01 Reply:'],
#  1361: ['Request:05-01-2021 01:04 Reply:05-01-2021 02:38'],
#  1362: ['Request:05-01-2021 01:03 Reply:05-01-2021 01:23'],
#  1364: ['Request:05-01-2021 06:12 Reply:05-01-2021 07:40'],
#  1366: ['Request:05-01-2021 01:54 Reply:05-01-2021 02:43'],
#  1370: ['Request:05-01-2021 01:33 Reply:05-01-2021 02:16'],
#  1371: ['Request:05-01-2021 04:58 Reply:05-01-2021 07:10'],
#  1374: ['Request:05-01-2021 02:34 Reply:05-01-2021 02:48'],
#  1375: ['Request:05-01-2021 01:58 Reply:05-01-2021 02:41'],
#  1376: ['Request:05-01-2021 01:22 Reply:05-01-2021 02:40'],
#  1377: ['Request:05-01-2021 01:31 Reply:05-01-2021 01:57'],
#  1378: ['Request:05-01-2021 03:17 Reply:',
#   'Request:05-01-2021 03:48 Reply:05-01-2021 04:45'],
#  1381: ['Request:05-01-2021 02:14 Reply:05-01-2021 04:01'],
#  1382: ['Request:05-01-2021 02:29 Reply:05-01-2021 02:42'],
#  1384: ['Request:05-01-2021 03:17 Reply:05-01-2021 05:13'],
#  1388: ['Request:05-01-2021 02:42 Reply:05-01-2021 03:59'],
#  1389: ['Request:05-01-2021 15:55 Reply:05-01-2021 16:44'],
#  1390: ['Request:05-01-2021 12:38 Reply:05-01-2021 23:16'],
#  1391: ['Request:05-01-2021 11:42 Reply:05-01-2021 13:29'],
#  1393: ['Request:05-01-2021 12:16 Reply:05-01-2021 18:23'],
#  1395: ['Request:05-01-2021 11:19 Reply:05-01-2021 13:40'],
#  1397: ['Request:05-01-2021 13:05 Reply:05-01-2021 15:25'],
#  1401: ['Request:05-01-2021 19:43 Reply:05-01-2021 20:40'],
#  1406: ['Request:05-01-2021 17:56 Reply:05-01-2021 19:00'],
#  1407: ['Request:05-01-2021 19:38 Reply:05-01-2021 20:23',
#   'Request:05-01-2021 20:30 Reply:06-01-2021 00:21'],
#  1410: ['Request:05-01-2021 12:44 Reply:05-01-2021 15:26'],
#  1411: ['Request:05-01-2021 14:54 Reply:05-01-2021 16:08'],
#  1412: ['Request:05-01-2021 14:00 Reply:'],
#  1415: ['Request:05-01-2021 14:09 Reply:'],
#  1420: ['Request:05-01-2021 22:43 Reply:06-01-2021 00:19'],
#  1423: ['Request:05-01-2021 18:54 Reply:05-01-2021 20:58'],
#  1427: ['Request:05-01-2021 20:25 Reply:05-01-2021 20:51'],
#  1434: ['Request:05-01-2021 03:53 Reply:05-01-2021 07:13',
#   'Request:05-01-2021 06:30 Reply:07-01-2021 22:02',
#   'Request:05-01-2021 06:52 Reply:05-01-2021 19:45'],
#  1435: ['Request:05-01-2021 04:03 Reply:05-01-2021 04:31'],
#  1437: ['Request:05-01-2021 04:23 Reply:'],
#  1438: ['Request:05-01-2021 04:50 Reply:05-01-2021 07:31'],
#  1440: ['Request:05-01-2021 07:53 Reply:05-01-2021 09:07'],
#  1442: ['Request:05-01-2021 11:14 Reply:05-01-2021 17:05'],
#  1443: ['Request:05-01-2021 11:14 Reply:05-01-2021 11:49',
#   'Request:05-01-2021 11:58 Reply:05-01-2021 12:10'],
#  1445: ['Request:05-01-2021 10:22 Reply:05-01-2021 11:18'],
#  1448: ['Request:05-01-2021 10:31 Reply:05-01-2021 12:06'],
#  1449: ['Request:05-01-2021 11:21 Reply:05-01-2021 11:46'],
#  1450: ['Request:05-01-2021 21:10 Reply:06-01-2021 00:20'],
#  1451: ['Request:05-01-2021 20:27 Reply:05-01-2021 21:36'],
#  1454: ['Request:05-01-2021 19:14 Reply:05-01-2021 19:36'],
#  1460: ['Request:05-01-2021 14:36 Reply:05-01-2021 15:02'],
#  1461: ['Request:05-01-2021 14:15 Reply:05-01-2021 18:54',
#   'Request:05-01-2021 14:59 Reply:05-01-2021 15:40',
#   'Request:05-01-2021 15:37 Reply:05-01-2021 16:26',
#   'Request:05-01-2021 15:53 Reply:05-01-2021 16:55'],
#  1464: ['Request:05-01-2021 13:58 Reply:05-01-2021 15:29'],
#  1466: ['Request:05-01-2021 17:51 Reply:05-01-2021 19:03'],
#  1467: ['Request:05-01-2021 18:45 Reply:05-01-2021 20:15'],
#  1469: ['Request:05-01-2021 15:25 Reply:05-01-2021 15:35'],
#  1470: ['Request:05-01-2021 15:12 Reply:05-01-2021 15:49'],
#  1476: ['Request:05-01-2021 15:20 Reply:05-01-2021 15:42'],
#  1480: ['Request:05-01-2021 23:09 Reply:'],
#  1482: ['Request:05-01-2021 20:56 Reply:05-01-2021 21:31'],
#  1483: ['Request:05-01-2021 21:37 Reply:'],
#  1488: ['Request:05-01-2021 13:11 Reply:05-01-2021 13:58'],
#  1489: ['Request:05-01-2021 11:50 Reply:05-01-2021 13:39'],
#  1490: ['Request:05-01-2021 12:26 Reply:05-01-2021 13:34'],
#  1491: ['Request:05-01-2021 14:50 Reply:05-01-2021 15:50'],
#  1492: ['Request:05-01-2021 17:16 Reply:05-01-2021 17:40'],
#  1493: ['Request:05-01-2021 14:54 Reply:05-01-2021 15:33'],
#  1495: ['Request:05-01-2021 18:02 Reply:05-01-2021 18:43',
#   'Request:05-01-2021 18:04 Reply:05-01-2021 20:57',
#   'Request:05-01-2021 18:05 Reply:05-01-2021 18:44'],
#  1497: ['Request:05-01-2021 14:24 Reply:05-01-2021 14:56'],
#  1503: ['Request:05-01-2021 14:32 Reply:'],
#  1504: ['Request:05-01-2021 05:58 Reply:05-01-2021 07:14'],
#  1508: ['Request:05-01-2021 18:17 Reply:05-01-2021 19:12'],
#  1511: ['Request:05-01-2021 18:57 Reply:06-01-2021 00:22'],
#  1514: ['Request:05-01-2021 19:05 Reply:05-01-2021 20:57'],
#  1517: ['Request:05-01-2021 17:00 Reply:05-01-2021 18:40'],
#  1518: ['Request:05-01-2021 17:11 Reply:05-01-2021 17:42'],
#  1519: ['Request:05-01-2021 17:42 Reply:17-01-2021 11:44'],
#  1521: ['Request:05-01-2021 17:10 Reply:05-01-2021 17:42'],
#  1524: ['Request:05-01-2021 20:34 Reply:05-01-2021 21:06'],
#  1529: ['Request:05-01-2021 17:14 Reply:05-01-2021 17:50'],
#  1533: ['Request:05-01-2021 05:08 Reply:'],
#  1538: ['Request:05-01-2021 18:22 Reply:05-01-2021 19:45'],
#  1540: ['Request:05-01-2021 17:19 Reply:05-01-2021 17:54'],
#  1542: ['Request:05-01-2021 11:43 Reply:05-01-2021 12:15'],
#  1547: ['Request:05-01-2021 08:38 Reply:05-01-2021 17:04',
#   'Request:05-01-2021 08:39 Reply:',
#   'Request:05-01-2021 09:34 Reply:05-01-2021 22:22',
#   'Request:05-01-2021 09:52 Reply:',
#   'Request:05-01-2021 12:07 Reply:05-01-2021 13:26',
#   'Request:05-01-2021 13:36 Reply:05-01-2021 19:45',
#   'Request:05-01-2021 13:50 Reply:05-01-2021 14:53'],
#  1548: ['Request:05-01-2021 09:22 Reply:'],
#  1552: ['Request:05-01-2021 16:25 Reply:05-01-2021 17:48'],
#  1554: ['Request:05-01-2021 16:28 Reply:05-01-2021 17:32'],
#  1555: ['Request:05-01-2021 21:19 Reply:06-01-2021 00:20'],
#  1557: ['Request:05-01-2021 21:08 Reply:06-01-2021 00:21'],
#  1561: ['Request:05-01-2021 12:31 Reply:05-01-2021 12:59'],
#  1562: ['Request:05-01-2021 10:34 Reply:05-01-2021 23:05',
#   'Request:05-01-2021 10:38 Reply:',
#   'Request:05-01-2021 17:20 Reply:05-01-2021 17:37',
#   'Request:05-01-2021 17:24 Reply:'],
#  1567: ['Request:05-01-2021 15:19 Reply:05-01-2021 16:02'],
#  1570: ['Request:05-01-2021 20:37 Reply:06-01-2021 00:22'],
#  1572: ['Request:06-01-2021 00:09 Reply:06-01-2021 00:38'],
#  1573: ['Request:05-01-2021 21:23 Reply:05-01-2021 22:46'],
#  1574: ['Request:05-01-2021 20:28 Reply:'],
#  1582: ['Request:05-01-2021 21:36 Reply:05-01-2021 22:07'],
#  1585: ['Request:05-01-2021 21:33 Reply:05-01-2021 22:21'],
#  1589: ['Request:05-01-2021 11:41 Reply:05-01-2021 13:34'],
#  1592: ['Request:05-01-2021 15:37 Reply:05-01-2021 16:02'],
#  1595: ['Request:05-01-2021 11:07 Reply:05-01-2021 12:12'],
#  1596: ['Request:05-01-2021 12:39 Reply:'],
#  1600: ['Request:05-01-2021 03:15 Reply:'],
#  1601: ['Request:05-01-2021 03:53 Reply:05-01-2021 13:37'],
#  1608: ['Request:05-01-2021 05:13 Reply:'],
#  1609: ['Request:05-01-2021 05:20 Reply:05-01-2021 06:28'],
#  1610: ['Request:05-01-2021 03:47 Reply:05-01-2021 05:08'],
#  1611: ['Request:05-01-2021 06:48 Reply:05-01-2021 07:29'],
# ...
#  1738: ['Request:06-01-2021 14:10 Reply:06-01-2021 16:13'],
#  1741: ['Request:06-01-2021 15:17 Reply:06-01-2021 15:53'],
#  1744: ['Request:06-01-2021 12:01 Reply:06-01-2021 13:07'],
#  1746: ['Request:06-01-2021 12:16 Reply:06-01-2021 13:36'],
#  1748: ['Request:06-01-2021 12:09 Reply:06-01-2021 13:08'],
#  1749: ['Request:06-01-2021 15:18 Reply:'],
#  1751: ['Request:06-01-2021 15:20 Reply:06-01-2021 16:26'],
#  1756: ['Request:06-01-2021 21:04 Reply:06-01-2021 21:21'],
#  1762: ['Request:06-01-2021 10:46 Reply:06-01-2021 13:36'],
#  1764: ['Request:06-01-2021 10:09 Reply:06-01-2021 13:37',
#   'Request:06-01-2021 11:07 Reply:06-01-2021 11:34'],
#  1766: ['Request:06-01-2021 16:51 Reply:06-01-2021 17:23'],
#  1767: ['Request:06-01-2021 17:18 Reply:06-01-2021 18:33'],
#  1768: ['Request:06-01-2021 19:55 Reply:06-01-2021 21:42',
#   'Request:06-01-2021 20:00 Reply:06-01-2021 23:13',
#   'Request:06-01-2021 20:15 Reply:06-01-2021 20:29'],
#  1770: ['Request:06-01-2021 16:58 Reply:06-01-2021 17:11'],
#  1771: ['Request:06-01-2021 17:09 Reply:06-01-2021 17:22',
#   'Request:06-01-2021 17:10 Reply:06-01-2021 17:22'],
#  1775: ['Request:06-01-2021 08:29 Reply:06-01-2021 09:52'],
#  1783: ['Request:07-01-2021 00:52 Reply:'],
#  1789: ['Request:06-01-2021 19:59 Reply:06-01-2021 21:55'],
#  1790: ['Request:06-01-2021 17:18 Reply:06-01-2021 19:29'],
#  1792: ['Request:06-01-2021 18:51 Reply:06-01-2021 19:41'],
#  1795: ['Request:06-01-2021 18:58 Reply:06-01-2021 20:42'],
#  1796: ['Request:06-01-2021 19:32 Reply:'],
#  1799: ['Request:06-01-2021 13:42 Reply:'],
#  1807: ['Request:06-01-2021 09:28 Reply:06-01-2021 10:09'],
#  1809: ['Request:06-01-2021 11:51 Reply:06-01-2021 13:34'],
#  1813: ['Request:06-01-2021 12:55 Reply:06-01-2021 13:37',
#   'Request:06-01-2021 13:05 Reply:06-01-2021 13:56'],
#  1814: ['Request:06-01-2021 15:21 Reply:06-01-2021 15:50'],
#  1815: ['Request:06-01-2021 23:31 Reply:'],
#  1817: ['Request:06-01-2021 22:14 Reply:06-01-2021 23:23'],
#  1818: ['Request:07-01-2021 02:35 Reply:07-01-2021 02:41'],
#  1820: ['Request:06-01-2021 22:41 Reply:06-01-2021 23:59'],
#  1822: ['Request:06-01-2021 18:59 Reply:06-01-2021 19:42'],
#  1823: ['Request:06-01-2021 20:02 Reply:06-01-2021 23:14'],
#  1824: ['Request:06-01-2021 23:12 Reply:07-01-2021 01:55'],
#  1825: ['Request:06-01-2021 21:03 Reply:06-01-2021 21:30'],
#  1833: ['Request:06-01-2021 19:51 Reply:06-01-2021 19:52'],
#  1834: ['Request:06-01-2021 21:32 Reply:06-01-2021 22:48'],
#  1836: ['Request:06-01-2021 23:00 Reply:07-01-2021 01:55'],
#  1838: ['Request:06-01-2021 21:21 Reply:'],
#  1839: ['Request:06-01-2021 22:58 Reply:'],
#  1841: ['Request:06-01-2021 23:24 Reply:'],
#  1844: ['Request:06-01-2021 20:57 Reply:17-01-2021 11:44'],
#  1846: ['Request:06-01-2021 21:08 Reply:06-01-2021 22:52'],
#  1848: ['Request:06-01-2021 20:58 Reply:06-01-2021 22:05'],
#  1850: ['Request:06-01-2021 01:26 Reply:'],
#  1851: ['Request:06-01-2021 01:30 Reply:06-01-2021 03:14',
#   'Request:06-01-2021 04:59 Reply:06-01-2021 07:48'],
#  1858: ['Request:06-01-2021 01:47 Reply:06-01-2021 03:31'],
#  1862: ['Request:06-01-2021 04:49 Reply:06-01-2021 05:59',
#   'Request:06-01-2021 04:56 Reply:06-01-2021 06:16'],
#  1865: ['Request:06-01-2021 02:48 Reply:06-01-2021 07:48'],
#  1867: ['Request:06-01-2021 00:51 Reply:06-01-2021 01:12'],
#  1872: ['Request:06-01-2021 05:59 Reply:06-01-2021 06:56'],
#  1873: ['Request:06-01-2021 05:27 Reply:06-01-2021 06:07'],
#  1877: ['Request:06-01-2021 07:28 Reply:06-01-2021 07:52',
#   'Request:06-01-2021 07:58 Reply:06-01-2021 08:07',
#   'Request:06-01-2021 09:25 Reply:06-01-2021 13:59'],
#  1883: ['Request:06-01-2021 06:33 Reply:06-01-2021 08:40'],
#  1885: ['Request:06-01-2021 09:41 Reply:06-01-2021 10:18',
#   'Request:06-01-2021 10:09 Reply:06-01-2021 11:42'],
#  1890: ['Request:06-01-2021 10:04 Reply:06-01-2021 13:38',
#   'Request:06-01-2021 10:49 Reply:06-01-2021 11:11'],
#  1892: ['Request:06-01-2021 09:09 Reply:06-01-2021 10:24'],
#  1894: ['Request:06-01-2021 09:08 Reply:06-01-2021 10:10'],
#  1895: ['Request:06-01-2021 03:18 Reply:06-01-2021 03:53'],
#  1896: ['Request:06-01-2021 03:31 Reply:'],
#  1897: ['Request:06-01-2021 06:37 Reply:06-01-2021 07:47'],
#  1899: ['Request:06-01-2021 03:33 Reply:'],
#  1900: ['Request:06-01-2021 06:01 Reply:06-01-2021 06:56'],
#  1906: ['Request:06-01-2021 06:22 Reply:06-01-2021 07:22',
#   'Request:06-01-2021 07:53 Reply:06-01-2021 11:04'],
#  1907: ['Request:06-01-2021 04:43 Reply:06-01-2021 06:20'],
#  1912: ['Request:06-01-2021 06:53 Reply:06-01-2021 07:47',
#   'Request:06-01-2021 06:54 Reply:06-01-2021 07:22'],
#  1913: ['Request:06-01-2021 04:52 Reply:06-01-2021 06:16'],
#  1914: ['Request:06-01-2021 04:43 Reply:06-01-2021 07:17'],
#  1916: ['Request:06-01-2021 02:22 Reply:06-01-2021 05:45'],
#  1917: ['Request:06-01-2021 01:40 Reply:06-01-2021 02:58'],
#  1919: ['Request:06-01-2021 01:40 Reply:06-01-2021 05:14',
#   'Request:06-01-2021 04:42 Reply:06-01-2021 04:54'],
#  1924: ['Request:06-01-2021 05:02 Reply:06-01-2021 06:18'],
#  1928: ['Request:06-01-2021 02:09 Reply:06-01-2021 06:05'],
#  1938: ['Request:06-01-2021 02:01 Reply:06-01-2021 03:09'],
#  1939: ['Request:06-01-2021 06:19 Reply:06-01-2021 07:33'],
#  1941: ['Request:06-01-2021 02:24 Reply:06-01-2021 04:06'],
#  1946: ['Request:06-01-2021 02:27 Reply:06-01-2021 06:00'],
#  1950: ['Request:06-01-2021 04:08 Reply:06-01-2021 05:54',
#   'Request:06-01-2021 06:20 Reply:06-01-2021 08:55'],
#  1951: ['Request:06-01-2021 02:25 Reply:06-01-2021 02:30'],
#  1953: ['Request:06-01-2021 02:33 Reply:06-01-2021 02:52'],
#  1957: ['Request:07-01-2021 08:59 Reply:07-01-2021 13:08'],
#  1961: ['Request:07-01-2021 09:35 Reply:07-01-2021 10:14'],
#  1962: ['Request:07-01-2021 10:29 Reply:07-01-2021 10:54'],
#  1963: ['Request:07-01-2021 11:31 Reply:07-01-2021 14:52'],
#  1964: ['Request:07-01-2021 02:54 Reply:07-01-2021 03:07'],
#  1965: ['Request:07-01-2021 03:25 Reply:'],
#  1976: ['Request:07-01-2021 05:18 Reply:07-01-2021 06:48'],
#  1980: ['Request:07-01-2021 05:14 Reply:07-01-2021 05:37'],
#  1982: ['Request:07-01-2021 07:33 Reply:07-01-2021 07:39',
#   'Request:07-01-2021 08:00 Reply:07-01-2021 12:44',
#   'Request:07-01-2021 09:09 Reply:07-01-2021 10:49'],
#  1986: ['Request:07-01-2021 06:03 Reply:07-01-2021 07:30'],
#  1990: ['Request:07-01-2021 10:47 Reply:07-01-2021 13:06'],
#  1993: ['Request:07-01-2021 05:21 Reply:07-01-2021 06:46'],
#  1996: ['Request:07-01-2021 08:04 Reply:07-01-2021 09:04',
#   'Request:07-01-2021 08:56 Reply:07-01-2021 10:07'],
#  1999: ['Request:07-01-2021 11:53 Reply:07-01-2021 14:58',
#   'Request:07-01-2021 15:46 Reply:'],
#  2001: ['Request:07-01-2021 07:15 Reply:07-01-2021 10:22'],
#  2015: ['Request:07-01-2021 05:25 Reply:07-01-2021 07:24'],
#  2019: ['Request:07-01-2021 02:44 Reply:07-01-2021 04:44'],
#  2020: ['Request:07-01-2021 03:53 Reply:'],
#  2025: ['Request:07-01-2021 02:19 Reply:'],
#  2027: ['Request:07-01-2021 03:38 Reply:07-01-2021 04:44'],
#  2028: ['Request:07-01-2021 03:48 Reply:07-01-2021 12:52'],
#  2029: ['Request:07-01-2021 03:56 Reply:07-01-2021 06:48',
#   'Request:07-01-2021 04:05 Reply:'],
#  2030: ['Request:07-01-2021 01:09 Reply:07-01-2021 01:46'],
#  2031: ['Request:07-01-2021 01:46 Reply:07-01-2021 05:03'],
#  2032: ['Request:07-01-2021 02:18 Reply:07-01-2021 03:19'],
#  2035: ['Request:07-01-2021 16:18 Reply:07-01-2021 16:53'],
#  2036: ['Request:07-01-2021 13:40 Reply:07-01-2021 15:30'],
#  2037: ['Request:07-01-2021 13:09 Reply:07-01-2021 16:06'],
#  2039: ['Request:07-01-2021 14:07 Reply:07-01-2021 14:59'],
#  2040: ['Request:07-01-2021 16:53 Reply:07-01-2021 18:14',
#   'Request:07-01-2021 17:05 Reply:'],
#  2041: ['Request:07-01-2021 17:12 Reply:07-01-2021 18:26'],
#  2042: ['Request:07-01-2021 22:34 Reply:07-01-2021 23:45'],
#  2044: ['Request:08-01-2021 00:17 Reply:', 'Request:08-01-2021 02:26 Reply:'],
#  2046: ['Request:08-01-2021 00:58 Reply:'],
#  2048: ['Request:07-01-2021 22:50 Reply:07-01-2021 22:54'],
#  2050: ['Request:07-01-2021 23:13 Reply:07-01-2021 23:35'],
#  2051: ['Request:08-01-2021 01:00 Reply:08-01-2021 05:42'],
#  2053: ['Request:07-01-2021 23:50 Reply:07-01-2021 23:53'],
#  2055: ['Request:08-01-2021 01:37 Reply:08-01-2021 04:38'],
#  2057: ['Request:08-01-2021 01:23 Reply:08-01-2021 03:50',
#   'Request:08-01-2021 03:11 Reply:08-01-2021 05:33'],
#  2059: ['Request:07-01-2021 23:42 Reply:07-01-2021 23:52'],
#  2064: ['Request:07-01-2021 01:38 Reply:07-01-2021 02:28'],
#  2065: ['Request:07-01-2021 02:15 Reply:07-01-2021 03:18'],
#  2067: ['Request:07-01-2021 01:31 Reply:07-01-2021 03:19'],
#  2068: ['Request:07-01-2021 03:08 Reply:07-01-2021 03:21'],
#  2069: ['Request:07-01-2021 05:11 Reply:07-01-2021 12:52'],
#  2071: ['Request:07-01-2021 02:07 Reply:07-01-2021 02:32'],
#  2076: ['Request:07-01-2021 02:46 Reply:07-01-2021 03:16'],
#  2077: ['Request:07-01-2021 02:04 Reply:07-01-2021 02:24'],
#  2079: ['Request:07-01-2021 04:32 Reply:'],
#  2080: ['Request:07-01-2021 02:03 Reply:07-01-2021 02:19'],
#  2086: ['Request:07-01-2021 16:30 Reply:07-01-2021 18:04'],
#  2087: ['Request:07-01-2021 16:42 Reply:07-01-2021 20:29'],
#  2096: ['Request:08-01-2021 03:49 Reply:08-01-2021 04:38'],
#  2100: ['Request:07-01-2021 23:49 Reply:08-01-2021 00:14'],
#  2101: ['Request:08-01-2021 01:34 Reply:08-01-2021 04:45'],
#  2102: ['Request:08-01-2021 00:19 Reply:08-01-2021 00:28'],
#  2106: ['Request:08-01-2021 04:30 Reply:08-01-2021 04:38'],
#  2108: ['Request:08-01-2021 01:50 Reply:08-01-2021 05:40',
#   'Request:08-01-2021 03:28 Reply:08-01-2021 04:15'],
#  2110: ['Request:08-01-2021 00:00 Reply:08-01-2021 04:02'],
#  2111: ['Request:08-01-2021 00:30 Reply:'],
#  2115: ['Request:07-01-2021 15:40 Reply:07-01-2021 16:44'],
#  2116: ['Request:07-01-2021 13:57 Reply:07-01-2021 16:19',
#   'Request:07-01-2021 16:39 Reply:07-01-2021 17:47'],
#  2120: ['Request:07-01-2021 13:31 Reply:07-01-2021 15:47'],
#  2123: ['Request:07-01-2021 16:11 Reply:07-01-2021 17:27'],
#  2126: ['Request:07-01-2021 16:40 Reply:07-01-2021 18:56'],
#  2128: ['Request:07-01-2021 15:42 Reply:07-01-2021 15:46'],
#  2129: ['Request:07-01-2021 17:27 Reply:07-01-2021 18:33'],
#  2130: ['Request:07-01-2021 14:33 Reply:07-01-2021 16:19'],
#  2132: ['Request:07-01-2021 16:15 Reply:07-01-2021 16:59'],
#  2137: ['Request:07-01-2021 18:11 Reply:07-01-2021 21:33'],
#  2138: ['Request:07-01-2021 20:42 Reply:07-01-2021 21:22'],
#  2140: ['Request:07-01-2021 15:21 Reply:07-01-2021 15:44'],
#  2144: ['Request:07-01-2021 15:36 Reply:07-01-2021 16:25'],
#  2145: ['Request:07-01-2021 16:08 Reply:07-01-2021 17:21'],
#  2147: ['Request:07-01-2021 17:25 Reply:07-01-2021 17:58'],
#  2148: ['Request:07-01-2021 15:28 Reply:07-01-2021 15:43'],
#  2149: ['Request:07-01-2021 18:06 Reply:08-01-2021 07:22'],
#  2152: ['Request:07-01-2021 15:57 Reply:07-01-2021 16:03'],
#  2154: ['Request:07-01-2021 20:26 Reply:08-01-2021 03:23'],
#  2163: ['Request:07-01-2021 10:33 Reply:07-01-2021 11:18'],
#  2164: ['Request:07-01-2021 19:59 Reply:08-01-2021 04:39',
#   'Request:07-01-2021 21:25 Reply:08-01-2021 03:17'],
#  2165: ['Request:07-01-2021 18:57 Reply:07-01-2021 19:34'],
#  2168: ['Request:07-01-2021 23:16 Reply:08-01-2021 04:45'],
#  2172: ['Request:07-01-2021 18:49 Reply:07-01-2021 19:41'],
#  2175: ['Request:07-01-2021 21:33 Reply:08-01-2021 03:23'],
#  2180: ['Request:07-01-2021 16:18 Reply:07-01-2021 17:39'],
#  2183: ['Request:07-01-2021 17:03 Reply:07-01-2021 18:55'],
#  2184: ['Request:07-01-2021 16:24 Reply:07-01-2021 17:47'],
#  2189: ['Request:07-01-2021 09:29 Reply:07-01-2021 10:25'],
#  2190: ['Request:07-01-2021 09:28 Reply:07-01-2021 10:37'],
#  2191: ['Request:07-01-2021 10:11 Reply:07-01-2021 11:01'],
#  2192: ['Request:07-01-2021 19:57 Reply:07-01-2021 20:14'],
#  2201: ['Request:07-01-2021 14:58 Reply:07-01-2021 15:34'],
#  2204: ['Request:07-01-2021 20:26 Reply:07-01-2021 22:15'],
#  2205: ['Request:07-01-2021 17:58 Reply:07-01-2021 19:54'],
#  2211: ['Request:07-01-2021 17:19 Reply:07-01-2021 18:18'],
#  2220: ['Request:07-01-2021 17:26 Reply:07-01-2021 18:11'],
#  2221: ['Request:07-01-2021 10:45 Reply:07-01-2021 11:42'],
#  2225: ['Request:07-01-2021 19:50 Reply:07-01-2021 20:15'],
#  2226: ['Request:07-01-2021 21:58 Reply:'],
#  2233: ['Request:07-01-2021 22:37 Reply:07-01-2021 22:58'],
#  2236: ['Request:07-01-2021 22:00 Reply:08-01-2021 00:32'],
#  2237: ['Request:07-01-2021 08:59 Reply:07-01-2021 10:17'],
#  2240: ['Request:07-01-2021 09:13 Reply:07-01-2021 10:11'],
#  2241: ['Request:07-01-2021 10:40 Reply:07-01-2021 11:18',
#   'Request:07-01-2021 11:34 Reply:07-01-2021 12:39'],
#  2244: ['Request:07-01-2021 07:30 Reply:07-01-2021 08:05'],
#  2245: ['Request:07-01-2021 10:07 Reply:07-01-2021 10:46'],
#  2247: ['Request:07-01-2021 10:49 Reply:07-01-2021 12:50'],
#  2251: ['Request:07-01-2021 22:06 Reply:07-01-2021 22:58'],
#  2252: ['Request:07-01-2021 20:10 Reply:07-01-2021 22:09'],
#  2255: ['Request:07-01-2021 20:53 Reply:07-01-2021 21:24'],
#  2256: ['Request:07-01-2021 22:32 Reply:08-01-2021 04:41'],
#  2258: ['Request:07-01-2021 20:26 Reply:07-01-2021 20:39'],
#  2261: ['Request:07-01-2021 12:38 Reply:07-01-2021 12:59'],
#  2262: ['Request:07-01-2021 14:50 Reply:07-01-2021 16:44'],
#  2263: ['Request:07-01-2021 12:00 Reply:07-01-2021 13:12',
#   'Request:07-01-2021 12:01 Reply:07-01-2021 14:05'],
#  2264: ['Request:07-01-2021 12:58 Reply:07-01-2021 13:43',
#   'Request:07-01-2021 13:54 Reply:07-01-2021 14:47'],
#  2266: ['Request:07-01-2021 12:04 Reply:07-01-2021 13:09'],
#  2268: ['Request:07-01-2021 13:26 Reply:07-01-2021 14:58'],
#  2273: ['Request:07-01-2021 23:34 Reply:08-01-2021 00:31'],
#  2278: ['Request:07-01-2021 12:49 Reply:07-01-2021 13:04'],
#  2280: ['Request:07-01-2021 12:05 Reply:'],
#  2281: ['Request:07-01-2021 12:17 Reply:07-01-2021 12:21'],
#  2287: ['Request:08-01-2021 00:02 Reply:08-01-2021 00:25'],
#  2298: ['Request:07-01-2021 14:57 Reply:07-01-2021 15:20'],
#  2304: ['Request:07-01-2021 11:53 Reply:07-01-2021 14:17'],
#  2308: ['Request:07-01-2021 12:48 Reply:07-01-2021 15:28'],
#  2311: ['Request:07-01-2021 12:13 Reply:07-01-2021 14:36'],
#  2316: ['Request:08-01-2021 02:02 Reply:08-01-2021 05:01'],
#  2317: ['Request:08-01-2021 03:17 Reply:08-01-2021 03:55',
#   'Request:08-01-2021 03:17 Reply:08-01-2021 04:05'],
#  2319: ['Request:08-01-2021 00:32 Reply:08-01-2021 02:37'],
#  2320: ['Request:08-01-2021 00:53 Reply:'],
#  2324: ['Request:08-01-2021 02:32 Reply:08-01-2021 05:34'],
#  2327: ['Request:08-01-2021 00:55 Reply:08-01-2021 01:11'],
#  2328: ['Request:08-01-2021 00:55 Reply:08-01-2021 02:49'],
#  2330: ['Request:08-01-2021 00:59 Reply:'],
#  2332: ['Request:08-01-2021 02:02 Reply:08-01-2021 07:11',
#   'Request:08-01-2021 05:07 Reply:'],
#  2333: ['Request:08-01-2021 01:02 Reply:08-01-2021 01:32'],
#  2334: ['Request:08-01-2021 01:07 Reply:08-01-2021 01:48'],
#  2335: ['Request:08-01-2021 01:36 Reply:'],
#  2336: ['Request:08-01-2021 01:30 Reply:08-01-2021 04:06'],
#  2337: ['Request:08-01-2021 04:02 Reply:08-01-2021 05:09'],
#  2339: ['Request:08-01-2021 03:42 Reply:08-01-2021 06:06'],
#  2341: ['Request:08-01-2021 02:19 Reply:08-01-2021 07:15'],
#  2342: ['Request:08-01-2021 05:04 Reply:08-01-2021 05:19'],
#  2343: ['Request:08-01-2021 06:03 Reply:'],
#  2345: ['Request:08-01-2021 05:45 Reply:08-01-2021 11:28',
#   'Request:08-01-2021 05:45 Reply:08-01-2021 06:37'],
#  2346: ['Request:08-01-2021 07:05 Reply:'],
#  2349: ['Request:08-01-2021 23:05 Reply:'],
#  2350: ['Request:08-01-2021 21:40 Reply:08-01-2021 22:16'],
#  2354: ['Request:08-01-2021 22:04 Reply:08-01-2021 22:35'],
#  2358: ['Request:08-01-2021 22:28 Reply:08-01-2021 23:47'],
#  2360: ['Request:09-01-2021 04:24 Reply:09-01-2021 05:52'],
#  2361: ['Request:08-01-2021 22:40 Reply:08-01-2021 23:52'],
#  2362: ['Request:08-01-2021 22:51 Reply:08-01-2021 23:25'],
#  2368: ['Request:09-01-2021 00:42 Reply:'],
#  2369: ['Request:08-01-2021 22:49 Reply:08-01-2021 23:15'],
#  2370: ['Request:08-01-2021 22:58 Reply:08-01-2021 23:22'],
#  2373: ['Request:08-01-2021 23:16 Reply:'],
#  2377: ['Request:09-01-2021 02:05 Reply:09-01-2021 02:41'],
#  2378: ['Request:08-01-2021 21:31 Reply:08-01-2021 23:41'],
#  2379: ['Request:08-01-2021 22:15 Reply:08-01-2021 23:41'],
#  2380: ['Request:08-01-2021 21:47 Reply:08-01-2021 23:58'],
#  2382: ['Request:09-01-2021 02:32 Reply:09-01-2021 03:01'],
#  2383: ['Request:08-01-2021 21:51 Reply:08-01-2021 22:06'],
#  2397: ['Request:09-01-2021 00:10 Reply:09-01-2021 00:46'],
#  ...}

# %% [markdown]
# As we saw above, we have used `.itmes()` method which we can reach to `keys and values` inside series and created `for loop` and splitted each values (text) with semicolon `;` and converted it to list.
# Now, we should convert dictionay to series.

# %%
series_consult_lst_1 = pd.Series(dict_consult)
series_consult_lst_1
# Out:
# 1        [Request:01-01-2021 23:38 Reply:02-01-2021 00:36]
# 6        [Request:02-01-2021 00:40 Reply:02-01-2021 01:...
# 7        [Request:02-01-2021 00:49 Reply:02-01-2021 01:39]
# 8        [Request:02-01-2021 03:24 Reply:02-01-2021 04:06]
# 11       [Request:01-01-2021 23:46 Reply:02-01-2021 00:29]
#                                ...
# 29950    [Request:31-03-2021 18:01 Reply:31-03-2021 18:12]
# 29951    [Request:31-03-2021 18:58 Reply:01-04-2021 00:37]
# 29952    [Request:31-03-2021 14:21 Reply:31-03-2021 14:...
# 29954    [Request:31-03-2021 15:13 Reply:31-03-2021 16:19]
# 29955    [Request:31-03-2021 14:37 Reply:31-03-2021 19:13]
# Length: 11508, dtype: object

# %% [markdown]
# ### second way by using built in functions

# %%
series_consult_lst_2 = series_consult_without_null_vals.apply(lambda x: x.split(';'))
series_consult_lst_2
# Out:
# 1        [Request:01-01-2021 23:38 Reply:02-01-2021 00:36]
# 6        [Request:02-01-2021 00:40 Reply:02-01-2021 01:...
# 7        [Request:02-01-2021 00:49 Reply:02-01-2021 01:39]
# 8        [Request:02-01-2021 03:24 Reply:02-01-2021 04:06]
# 11       [Request:01-01-2021 23:46 Reply:02-01-2021 00:29]
#                                ...
# 29950    [Request:31-03-2021 18:01 Reply:31-03-2021 18:12]
# 29951    [Request:31-03-2021 18:58 Reply:01-04-2021 00:37]
# 29952    [Request:31-03-2021 14:21 Reply:31-03-2021 14:...
# 29954    [Request:31-03-2021 15:13 Reply:31-03-2021 16:19]
# 29955    [Request:31-03-2021 14:37 Reply:31-03-2021 19:13]
# Name: CONSULTATIONS, Length: 11508, dtype: object

# %% [markdown]
# Let's take one index for example index 6

# %%
series_consult_lst_2[6]
# Out:
# ['Request:02-01-2021 00:40 Reply:02-01-2021 01:21',
#  'Request:02-01-2021 00:49 Reply:02-01-2021 01:30']

# %% [markdown]
# Let us check if this patient recieved two consultations in the original data

# %%
consultations.iloc[6][0]
# Out:
# 'Request:02-01-2021 00:40 Reply:02-01-2021 01:21;Request:02-01-2021 00:49 Reply:02-01-2021 01:30'

# %% [markdown]
# As we noted, this patient recieved two consultation, each one with Request and Reply

# %% [markdown]
# ### Compute length of single consultation

# %% [markdown]
# One more thing I would to check, How long single consultation ?

# %%
# let us print the first consultation of index six
series_consult_lst_2[6][0]
# Out:
# 'Request:02-01-2021 00:40 Reply:02-01-2021 01:21'

# %%
len(series_consult_lst_2[6][0])
# Out:
# 47

# %% [markdown]
# check all consultations should have the same length 47. if anyone has less than that, it means there is request without reply.

# %% [markdown]
# let us check that.

# %% [markdown]
# 1. we need to compute the lenght of each consultations.
# 2. extending all consultaions together in one lst.
# 3. converting lst to series and check number of unique values or by convert lst to set.
# 4. computing total of length consultations with 31.
# 5. extracting all indexes for these consultations with lenght 31.
# 6. checking if all consulations have the same lenght as consultatins indexes. Should be same length and finding these consultatins by indexes to see why they have 31 length.

# %% [markdown]
# #### 1st step
# - we need to compute the length of each consultation.
# - by use `apply` and `lambda` functions and list comperhension to compute the length of each value of consultation.

# %%
len_consutlation_lst = series_consult_lst_2.apply(lambda x: [len(n) for n in x])
len_consutlation_lst
# Out:
# 1            [47]
# 6        [47, 47]
# 7            [47]
# 8            [47]
# 11           [47]
#            ...
# 29950        [47]
# 29951        [47]
# 29952    [47, 47]
# 29954        [47]
# 29955        [47]
# Name: CONSULTATIONS, Length: 11508, dtype: object

# %% [markdown]
# As we saw above some indexes have more than one consultation, we need to join all consutations togther.

# %% [markdown]
# #### 2nd step
# - Extending all consultaions toghter to one list

# %%
total_len_consult_lst = []
for lst in len_consutlation_lst:
    total_len_consult_lst.extend(lst)
    
total_len_consult_lst[:10]
# Out:
# [47, 47, 47, 47, 47, 47, 47, 47, 47, 47]

# %% [markdown]
# ok, that's good, we have the lenght of each single consultation. Now we can find the unique of values for this list by convert list to set or to series.

# %% [markdown]
# **What were total consultations for each patient?**

# %%
len(total_len_consult_lst)
# Out:
# 13928

# %% [markdown]
# Good good, we have 13928 total consultations.

# %% [markdown]
# Now, we check all these have the same length 47 or not.

# %% [markdown]
# **Did there any consultatios without reply? If yes, how many did have?**

# %% [markdown]
# #### 3rd step
# converting list to series and check number of unique values or by convert list to set.

# %%
set(total_len_consult_lst)
# Out:
# {31, 47}

# %%
pd.Series(total_len_consult_lst).unique()
# Out:
# array([47, 31])

# %% [markdown]
# let's come back to our question if you have remembered.
#
# Do you think we have request date time without reply data time?
#
# Here we can say these consultations with lenght 31 have request without reply.

# %% [markdown]
# #### 4th step
# Computing total of length consultations with 31.

# %% [markdown]
# let's create for loop by use list comperhension and find only total consultations without reply

# %%
len([n for n in total_len_consult_lst if n==31])
# Out:
# 1208

# %% [markdown]
# #### 5th step
# Extracting all indexes for these consultations with lenght 31.

# %% [markdown]
# Why we are going to determining all indexes of consultations length = 31 ?
#
# Because, we want to check these indexes with original data indexs if they have the same lenght of selected consultations.

# %%
index_lst_31 = []
for i in len_consutlation_lst.index:
    if len(len_consutlation_lst[i]) > 1:
        for n in len_consutlation_lst[i]:
            if n == 31:
              index_lst_31.append(i)
    else:
        if len_consutlation_lst[i][0] == 31:
            index_lst_31.append(i)

# %% [markdown]
# How many indexes with 31 lengths?

# %%
len(index_lst_31)
# Out:
# 1208

# %% [markdown]
# Ok, we have `13928` total consultations, a `1208` without reply data time and `11720` with reply data time.

# %% [markdown]
# #### 6th step
# checking if all indexes have at least a one consultation with a length 31 and finding these consultatins by indexes to see why they have 31 length?

# %% [markdown]
# After we extracted all indexes of consultations with a lenght 31, we need indexes of these consultations (without reply) to check if they have request without reply or not.

# %% [markdown]
# Let us see the 1st ten indexes

# %%
index_lst_31[:10]
# Out:
# [31, 32, 39, 53, 56, 80, 97, 105, 176, 178]

# %% [markdown]
# **1st index**

# %%
series_consult_lst_2[31]
# Out:
# ['Request:01-01-2021 21:27 Reply:01-01-2021 22:12',
#  'Request:01-01-2021 21:28 Reply:']

# %% [markdown]
# **1st index in the original data**

# %%
consultations.iloc[31,:][0]
# Out:
# 'Request:01-01-2021 21:27 Reply:01-01-2021 22:12;Request:01-01-2021 21:28 Reply:'

# %% [markdown]
# As we saw above, this index has one consultation with reply date time and other consultation without reply date time. The first consultation has lenght 47 but the second has lenght 31.
#
# To prevent the confusing, some of indexes with multiple consultations and these might be with or without reply date time. As we saw in the index 31.

# %%
len(series_consult_lst_2[31][0])
# Out:
# 47

# %%
len(series_consult_lst_2[31][1])
# Out:
# 31

# %% [markdown]
# let us see the last ten indexes

# %%
index_lst_31[-10:]
# Out:
# [29702, 29727, 29766, 29812, 29861, 29861, 29866, 29878, 29885, 29889]

# %% [markdown]
# last index

# %%
series_consult_lst_2[29889]
# Out:
# ['Request:31-03-2021 04:33 Reply:',
#  'Request:31-03-2021 05:22 Reply:31-03-2021 05:28']

# %% [markdown]
# As we saw above, this index has two consulations first one without reply date time and second one with reply date time. The first consultation has lenght 31 but the second has lenght 47.

# %% [markdown]
# After we convert text (string) to list, let's move to next step.

# %% [markdown]
# #### determine indexes of consultations request and reply date time

# %%
consult_lst1 = series_consult_lst_2.apply(lambda x: [ x[i][8:25] +'  '+ x[i][31:] for i in range(len(x)) ])

# %%
consult_lst1
# Out:
# 1                    [01-01-2021 23:38   02-01-2021 00:36]
# 6        [02-01-2021 00:40   02-01-2021 01:21, 02-01-20...
# 7                    [02-01-2021 00:49   02-01-2021 01:39]
# 8                    [02-01-2021 03:24   02-01-2021 04:06]
# 11                   [01-01-2021 23:46   02-01-2021 00:29]
#                                ...
# 29950                [31-03-2021 18:01   31-03-2021 18:12]
# 29951                [31-03-2021 18:58   01-04-2021 00:37]
# 29952    [31-03-2021 14:21   31-03-2021 14:30, 31-03-20...
# 29954                [31-03-2021 15:13   31-03-2021 16:19]
# 29955                [31-03-2021 14:37   31-03-2021 19:13]
# Name: CONSULTATIONS, Length: 11508, dtype: object

# %% [markdown]
# ### Computing the duration between Request and Reply date time

# %% [markdown]
# $$Duration = Reply - Request$$

# %% [markdown]
# How we can determine indexes of request and reply dates times?
#
# let us take index 6.

# %%
consult_lst1[6]
# Out:
# ['02-01-2021 00:40   02-01-2021 01:21', '02-01-2021 00:49   02-01-2021 01:30']

# %% [markdown]
# As we saw above, each request and reply date time inside a single index in the list. Wait but if we have indexes without reply dates times.
#
# let us take another index 31.

# %%
consult_lst1[31]
# Out:
# ['01-01-2021 21:27   01-01-2021 22:12', '01-01-2021 21:28   ']

# %% [markdown]
# As we saw above, the first index with request and reply date time but the second without reply date time.

# %%
len('01-01-2021 21:27   01-01-2021 22:12')
# Out:
# 35

# %%
len('01-01-2021 21:27')
# Out:
# 16

# %% [markdown]
# from the text (string) of request date time, its length ends at index 16

# %%
len('01-01-2021 21:27   ')
# Out:
# 19

# %% [markdown]
# while reply date time, its length begin at index 19

# %% [markdown]
# we will use `to_datetime` function to convert request and reply text to date time and specify two parameters `errors` to ignore any request date time without reply date time and `dayfirst` as true because our date start with day not month.

# %%
consult_duration = consult_lst1.apply(lambda x: [pd.to_datetime(x[i][19:], errors='coerce',dayfirst=True) - pd.to_datetime(x[i][:16], errors='coerce', dayfirst=True) for i in range(len(x))])

# %%
consult_duration
# Out:
# 1                         [0 days 00:58:00]
# 6        [0 days 00:41:00, 0 days 00:41:00]
# 7                         [0 days 00:50:00]
# 8                         [0 days 00:42:00]
# 11                        [0 days 00:43:00]
#                         ...
# 29950                     [0 days 00:11:00]
# 29951                     [0 days 05:39:00]
# 29952    [0 days 00:09:00, 0 days 01:02:00]
# 29954                     [0 days 01:06:00]
# 29955                     [0 days 04:36:00]
# Name: CONSULTATIONS, Length: 11508, dtype: object

# %% [markdown]
# As you see above, we computed the duration of consulations by subtract replay date time from request date time.

# %% [markdown]
# Now, let us check if these durations correclty computed or not.
# 1. we will select randomly five indexes
# 2. then see each index in the list of durations and compare it with original request and reply date time

# %%
np.random.seed(47)
random_indexs = np.random.choice(consult_duration.index,5)

# %%
random_indexs
# Out:
# array([13390,  4649, 17243, 22829,  7271])

# %%
for i in random_indexs:
    print(f'Index No:   {i}')
    print(f'The duration/s of {i}: \n{consult_duration[i]}')
    print(f'Request and Reply date time after we extracted: \n{consult_lst1[i]}')
    print(f'Request and Reply dat time in the original data: \n{series_consult_lst_2[i]}')
    print('==================================')
# Out:
# Index No:   13390
# The duration/s of 13390:
# [Timedelta('0 days 00:56:00')]
# Request and Reply date time after we extracted:
# ['10-02-2021 13:40   10-02-2021 14:36']
# Request and Reply dat time in the original data:
# ['Request:10-02-2021 13:40 Reply:10-02-2021 14:36']
# ==================================
# Index No:   4649
# The duration/s of 4649:
# [Timedelta('0 days 00:15:00'), Timedelta('0 days 00:37:00')]
# Request and Reply date time after we extracted:
# ['14-01-2021 04:16   14-01-2021 04:31', '14-01-2021 04:32   14-01-2021 05:09']
# Request and Reply dat time in the original data:
# ['Request:14-01-2021 04:16 Reply:14-01-2021 04:31', 'Request:14-01-2021 04:32 Reply:14-01-2021 05:09']
# ==================================
# Index No:   17243
# The duration/s of 17243:
# [NaT]
# Request and Reply date time after we extracted:
# ['22-02-2021 16:29   ']
# Request and Reply dat time in the original data:
# ['Request:22-02-2021 16:29 Reply:']
# ==================================
# Index No:   22829
# The duration/s of 22829:
# [Timedelta('0 days 00:50:00')]
# Request and Reply date time after we extracted:
# ['11-03-2021 06:55   11-03-2021 07:45']
# Request and Reply dat time in the original data:
# ['Request:11-03-2021 06:55 Reply:11-03-2021 07:45']
# ==================================
# Index No:   7271
# The duration/s of 7271:
# [Timedelta('0 days 00:47:00')]
# Request and Reply date time after we extracted:
# ['22-01-2021 06:44   22-01-2021 07:31']
# Request and Reply dat time in the original data:
# ['Request:22-01-2021 06:44 Reply:22-01-2021 07:31']
# ==================================

# %% [markdown]
# Amazing work, All five indexes in the list of duration mached request and reply date time in the original data.
# look at index 17243 without reply data time, so the duration was NaT.

# %% [markdown]
# Now, we would like to know the maximum number of consultations.

# %%
series_consult_lst_2.apply(lambda x: len(x)).value_counts()
# Out:
# 1     9809
# 2     1242
# 3      303
# 4       89
# 5       35
# 6       21
# 7        5
# 8        3
# 10       1
# Name: CONSULTATIONS, dtype: int64

# %%
plt.figure(figsize=(12,8))

x = series_consult_lst_2.apply(lambda x: len(x)).value_counts().keys()
y = series_consult_lst_2.apply(lambda x: len(x)).value_counts(normalize=True).values.round(2) * 100

splot = sns.barplot(x,y)

for p in splot.patches:
    splot.annotate(format(p.get_height()), 
                   (p.get_x() + p.get_width() / 2, p.get_height()), 
                    ha = 'center', va = 'center', 
                    xytext = (0, 9), 
                    textcoords = 'offset points')
    
splot.set_yticklabels([str(round(s))+'%' for s in splot.get_yticks() ], fontsize = 12)
plt.title('Percentage of Consultation Number', fontsize=16);
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <ipython-input-104-cc8170bd0b4a>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   splot.set_yticklabels([str(round(s))+'%' for s in splot.get_yticks() ], fontsize = 12)

# %% [markdown]
# The maximum number of consultations was ten consultations happened once time "for one patinet" the maximum frequence was one consultation with 85%.
# let us see that index with ten consultations

# %% [markdown]
# Let us find the index of ten consulations

# %%
max_consultations = series_consult_lst_2.apply(lambda x: len(x)).max()
max_consultations
# Out:
# 10

# %%
series_consult_lst_2[series_consult_lst_2.apply(lambda x: len(x)) == max_consultations]
# Out:
# 14775    [Request:14-02-2021 20:28 Reply:14-02-2021 20:...
# Name: CONSULTATIONS, dtype: object

# %%
series_consult_lst_2[14775]
# Out:
# ['Request:14-02-2021 20:28 Reply:14-02-2021 20:35',
#  'Request:14-02-2021 23:28 Reply:15-02-2021 07:18',
#  'Request:14-02-2021 23:31 Reply:14-02-2021 23:40',
#  'Request:14-02-2021 23:40 Reply:15-02-2021 03:05',
#  'Request:14-02-2021 23:43 Reply:15-02-2021 01:39',
#  'Request:15-02-2021 02:06 Reply:15-02-2021 05:13',
#  'Request:15-02-2021 02:09 Reply:15-02-2021 02:58',
#  'Request:15-02-2021 02:13 Reply:15-02-2021 03:30',
#  'Request:15-02-2021 02:20 Reply:15-02-2021 02:31',
#  'Request:15-02-2021 02:21 Reply:15-02-2021 03:13']

# %% [markdown]
# After we validated durations with request and reply date time.
# Let us extend all durations of consultations toghter to find basic statistics "central tendency".

# %%
total_duration_lst = []
for lst in consult_duration:
    total_duration_lst.extend(lst)

# %%
consult_duration_df = pd.DataFrame(total_duration_lst, columns=['Consultations Durations'])

# %% [markdown]
# **How long consumeed consultation or the duration betweeen the request and reply?**

# %%
consult_duration_df.describe()
# Out:
#          Consultations Durations
# count                      12720
# mean   0 days 01:57:56.316037735
# std    0 days 08:25:37.195638597
# min              0 days 00:00:00
# 25%              0 days 00:32:00
# 50%              0 days 01:02:00
# 75%              0 days 01:53:00
# max             15 days 16:01:00

# %% [markdown]
# let us see the max duration of consultation.

# %%
# find the index of max duration of consultations
for i in consult_duration.index:
    for d in consult_duration[i]:
        if d == pd.to_timedelta('15 days 16:01:00'):
            print(f'{i}:', consult_duration[i])
# Out:
# 27: [Timedelta('15 days 16:01:00'), Timedelta('0 days 01:13:00')]

# %%
# find the value of this index [27] in the list of consultations
series_consult_lst_2[27]
# Out:
# ['Request:01-01-2021 19:44 Reply:17-01-2021 11:45',
#  'Request:01-01-2021 20:45 Reply:01-01-2021 21:58']

# %%
# check this index [27] in the list of consultations, does duration match request and reply date time?
consult_lst1[27]
# Out:
# ['01-01-2021 19:44   17-01-2021 11:45', '01-01-2021 20:45   01-01-2021 21:58']

# %%
# check this index [27] in the original data, does duration match request and reply date time?
consultations.iloc[27,:][0]
# Out:
# 'Request:01-01-2021 19:44 Reply:17-01-2021 11:45;Request:01-01-2021 20:45 Reply:01-01-2021 21:58'

# %% [markdown]
# As we see above, the maximum duration was in the index 27, it was matched the original data
